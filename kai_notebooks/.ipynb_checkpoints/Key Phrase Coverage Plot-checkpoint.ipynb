# %%
import pandas as pd
import numpy as np
import gzip
import ast

import string
import itertools
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
from keras.preprocessing.text import Tokenizer

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Using TensorFlow backend.

# %%
ITEM_ID = 'asin'
USER_ID = 'reviewerID'
REVIEW_TEXT = 'reviewText'
KEYPHRASE = 'keyVector'

# %%
cur_df = pd.read_csv('../data/CDsVinyl/Data.csv')
cur_df[REVIEW_TEXT] = cur_df[REVIEW_TEXT].astype('str')
cur_df[USER_ID] = cur_df[USER_ID].astype('str')
cur_df[ITEM_ID] = cur_df[ITEM_ID].astype('str')
cur_df[KEYPHRASE] = cur_df[KEYPHRASE].apply(lambda key: ast.literal_eval(key))
cur_df
# Out:
#         Unnamed: 0      reviewerID        asin  overall  unixReviewTime  \
# 0                0  A2GANR9I6XHTU9  0780018664      4.0      1169337600
# 1                1   ANCOMAI0I7LVG  0780018664      5.0      1213574400
# 2                2  A1GGOC9PVDXW7Z  0780018664      5.0      1268524800
# 3                3   A62G4QX6XQVLP  0780018664      5.0      1165190400
# 4                4  A2ILOYARQVO4K1  0780018664      4.0       989193600
# 5                5  A2XKQHB8VCUCJK  0780018664      5.0      1385942400
# 6                6    AIMR915K4YCN  0780018664      5.0      1083196800
# 7                7  A1GHUN5HXMHZ89  0780018664      5.0      1300406400
# 8                8  A2C7BOQVFH1HLE  0780018664      4.0      1302825600
# 9                9  A25FDX17O3QKLT  0780018664      5.0      1115769600
# 10              10  A29ND8RD38SEUZ  0780018664      5.0      1358899200
# 11              11  A16CZRQL23NOIW  0780018664      5.0      1135123200
# 12              12  A2BLITJITO97N5  0780018664      5.0      1102636800
# 13              13  A366S12KCZ280V  0780018664      5.0      1376524800
# 14              14   AS0IKFFQS2HD2  0780018664      5.0      1217894400
# 15              15  A1UI2N2LBGVKC7  0780018664      5.0       944697600
# 16              16  A34D06JL7LC6MU  0780018664      4.0      1159574400
# 17              17  A2D9IEFJGB483Q  0780018664      5.0      1016496000
# 18              18  A2NJO6YE954DBH  0780018664      5.0      1099094400
# 19              19  A25KKXUQQ0OLWB  0780018664      5.0      1254355200
# 20              20  A1D2AXVN20OQZD  0780018664      5.0      1111795200
# 21              21  A3QLAOOTFEHCJI  0780018664      4.0      1316304000
# 22              22  A1VXN0LM7NUQ3L  0780018664      5.0      1156982400
# 23              23   AMKZHBOK7VMQR  0780018664      5.0      1351468800
# 24              24  A2R1HAXRNU0QX7  0780018664      5.0      1326672000
# 25              25  A2EDZH51XHFA9B  0780018664      4.0      1072051200
# 26              26  A18I75O0V5RAH8  0780018664      5.0       968803200
# 27              27  A1WYIDGR8ZG21X  0780018664      5.0      1098921600
# 28              28  A18758S1PUYIDT  0780018664      5.0      1267401600
# 29              29  A3EFQNLPCV5XNV  0780607287      5.0      1367366400
# ...            ...             ...         ...      ...             ...
# 182473      182473   A9Q28YTLYREO7  B00JDB4PLM      4.0      1402358400
# 182474      182474  A24N1BAS3CU27H  B00JDB4PLM      4.0      1402358400
# 182475      182475  A27D6RT8D7AMPW  B00JDB4PLM      5.0      1403913600
# 182476      182476  A2KUXPRQMR2OET  B00JDB4PLM      5.0      1402876800
# 182477      182477  A3KJ6JAZPH382D  B00JDB4PLM      3.0      1405728000
# 182478      182478   AHBXZ9O7AL74G  B00JXETVRC      5.0      1404950400
# 182479      182479  A2A6S9FGQIX5JK  B00JXETVRC      4.0      1405987200
# 182480      182480  A3O2ZA4F8E8OFD  B00JXETVRC      3.0      1404864000
# 182481      182481  A3E4FVGQ7TMMUL  B00JXETVRC      4.0      1404864000
# 182482      182482  A34IBXM7E8CPWE  B00JXETVRC      5.0      1405900800
# 182483      182483  A20DZX38KRBIT8  B00JXETVRC      5.0      1405900800
# 182484      182484  A3U7247JF0L52E  B00JXETVRC      5.0      1404950400
# 182485      182485  A1650I94SH53EH  B00JXETVRC      5.0      1404864000
# 182486      182486   AGS0UHWMBLX24  B00JXETVRC      5.0      1405814400
# 182487      182487  A1NF9WS7RR82MX  B00JXETVRC      4.0      1404777600
# 182488      182488  A2PJBX24OT9534  B00JXETVRC      4.0      1405468800
# 182489      182489  A15YPJLKLZS0MK  B00JXETVRC      3.0      1404950400
# 182490      182490  A3BXZ1EXCSCCSY  B00JXETVRC      5.0      1404777600
# 182491      182491   AY6VLDGM9D9PP  B00JXETVRC      4.0      1405209600
# 182492      182492  A1432KCCCZL550  B00JXETVRC      3.0      1405987200
# 182493      182493  A1A63EDKHNUFAO  B00JXETVRC      5.0      1405468800
# 182494      182494   AIDFLFUKJ657I  B00JXETVRC      5.0      1405296000
# 182495      182495   A3ZBLSAPZB9LE  B00JXETVRC      4.0      1405987200
# 182496      182496   AT29FDX10O5HN  B00JXETVRC      2.0      1405123200
# 182497      182497  A3QTSCTRZF3VGY  B00JXETVRC      5.0      1405641600
# 182498      182498  A3KJ6JAZPH382D  B00JXETVRC      4.0      1405036800
# 182499      182499   A3Q4XAQXKKV6V  B00JXETVRC      3.0      1404950400
# 182500      182500  A1HD9GFICWP02B  B00JXETVRC      5.0      1404777600
# 182501      182501  A3O536E2YOKK4Y  B00JXETVRC      5.0      1405036800
# 182502      182502   ACDE61HYM66YQ  B00JXETVRC      5.0      1404777600
#
#                                                reviewText  \
# 0       Filmed in 1931 this is the first serial killer...
# 1       My feelings for this iconic piece of filmmakin...
# 2       The title M comes from a chalk mark (for 'murd...
# 3       This film is easily in the Top 5 of Fritz Lang...
# 4       Dark, disturbingly satirical, humorous exactly...
# 5       &#34;M&#34; is a German expressionist film dir...
# 6       While watching this story unfold, I found myse...
# 7       I don't know if it is in writing somewhere, bu...
# 8       This is the first Criterion release that I've ...
# 9       This famous Fritz Lang classic is about a chil...
# 10      THE GERMAN BLU-RAY HAS THE MOST COMPLETE VERSI...
# 11      This picture adds another superb guerdon to th...
# 12      "M" is one of the greatest German films ever m...
# 13      and this is one of the most suspenseful movies...
# 14      Criterion has done it right again by presentin...
# 15      'M' was a film that was as beyond its time as ...
# 16      "M" is a film that is 75 years old, having cam...
# 17      I am a fan of Fritz Lang, but not a fan of mur...
# 18      "Just you wait a little while,The nasty man in...
# 19      This is a chilling film about a child murderer...
# 20      This is more a review for the justice Criterio...
# 21      Some critics/historians believe "M" to be an e...
# 22      what makes a man kill young children?even he h...
# 23      Fritz Lang's M features a young Peter Lorre as...
# 24      M is an extremely impressive movie...but very ...
# 25      M (Fritz Lang, 1931)It has been said that behi...
# 26      Some film historics consider it the best film ...
# 27      This film breathes with the gritty textures an...
# 28      spoilers.This is a great story of an entire ci...
# 29      Loved this movie as a kid and still do now. A ...
# ...                                                   ...
# 182473  to me Jack White gets it as a musician in that...
# 182474  I fell in love with Jack White's work on "Elep...
# 182475  Excellent follow-up to his debut &#34;Blunderb...
# 182476  Jack Whites requiem is the thing right now in ...
# 182477  A step back from his solo debut, "Blunderbuss,...
# 182478  And Faulkner is fantastic. He's a fantastic fa...
# 182479  Well, I have to eat crow! I was one of the man...
# 182480  I admire this band's endurance and longevity a...
# 182481  Think about this: how many bands have embarked...
# 182482  I was shocked to hear Priest was coming out wi...
# 182483  This is what real music is all about.  Some pe...
# 182484  I bought this the day it came out and have bee...
# 182485  THE MIGHTY JUDAS PRIEST HAVE RELEASED A GREAT ...
# 182486  When I first got this CD I was a bit skeptical...
# 182487  With a band lke Judas Priest, you're going to ...
# 182488  *This is a review for the deluxe version of th...
# 182489  This is a very heavy album with references to ...
# 182490  Whoa, awesome. Beat my expectations. Dare I sa...
# 182491  Judas Priest is simply one of the greatest met...
# 182492  I suppose this is where I should put the oblig...
# 182493  Excellent album. Judas Priest never ever disap...
# 182494  this is an awesome new album by judas preist i...
# 182495  First off, I am a huge Priest fan. This album ...
# 182496  The music is hard, but its not a classic. I'm ...
# 182497  Back to their strengths as one of the great me...
# 182498  Judas Priest last appeared in the form of a me...
# 182499  I like this new cd but I don't love it. I boug...
# 182500  Redeemer of Souls is a feast of Judas Priest h...
# 182501  ...and maybe since SCREAMING FOR VENGEANCE.My ...
# 182502  This guy are the true king of metal. there not...
#
#                                                    review  \
# 0       ['filmed', 'first', 'serial', 'killer', 'movie...
# 1       ['feeling', 'iconic', 'piece', 'filmmaking', '...
# 2       ['title', 'come', 'chalk', 'mark', 'murderer',...
# 3       ['film', 'easily', 'top', 'fritz', 'lang', 'be...
# 4       ['dark', 'disturbingly', 'satirical', 'humorou...
# 5       ['german', 'expressionist', 'film', 'directed'...
# 6       ['watching', 'story', 'unfold', 'found', 'quit...
# 7       ['nt', 'know', 'writing', 'somewhere', 'guess'...
# 8       ['first', 'criterion', 'release', 'ever', 'see...
# 9       ['famous', 'fritz', 'lang', 'classic', 'child'...
# 10      ['german', 'blu', 'ray', 'complete', 'version'...
# 11      ['picture', 'add', 'another', 'superb', 'guerd...
# 12      ['one', 'greatest', 'german', 'film', 'ever', ...
# 13      ['one', 'suspenseful', 'movie', 'ever', 'view'...
# 14      ['criterion', 'done', 'right', 'presenting', '...
# 15      ['film', 'beyond', 'time', 'enigmatic', 'title...
# 16      ['film', 'year', 'old', 'came', 'also', 'germa...
# 17      ['fan', 'fritz', 'lang', 'fan', 'murder', 'fil...
# 18      ['wait', 'little', 'nasty', 'man', 'black', 'c...
# 19      ['chilling', 'film', 'child', 'murderer', 'ter...
# 20      ['review', 'justice', 'criterion', 'done', 'fr...
# 21      ['critic', 'historian', 'believe', 'early', 'l...
# 22      ['make', 'man', 'kill', 'young', 'child', 'eve...
# 23      ['fritz', 'lang', 'feature', 'young', 'peter',...
# 24      ['extremely', 'impressive', 'movie', 'difficul...
# 25      ['fritz', 'lang', 'said', 'behind', 'every', '...
# 26      ['film', 'historics', 'consider', 'best', 'fil...
# 27      ['film', 'breathes', 'gritty', 'texture', 'des...
# 28      ['spoiler', 'great', 'story', 'entire', 'city'...
# 29      ['loved', 'movie', 'kid', 'still', 'remake', '...
# ...                                                   ...
# 182473  ['jack', 'white', 'get', 'musician', 'feel', '...
# 182474  ['fell', 'love', 'jack', 'white', 'work', 'ele...
# 182475  ['excellent', 'follow', 'debut', 'blunderbuss'...
# 182476  ['jack', 'white', 'requiem', 'thing', 'right',...
# 182477  ['step', 'back', 'solo', 'debut', 'blunderbuss...
# 182478  ['faulkner', 'fantastic', 'fantastic', 'fast',...
# 182479  ['well', 'eat', 'crow', 'one', 'many', 'skepti...
# 182480  ['admire', 'band', 'endurance', 'longevity', '...
# 182481  ['think', 'many', 'band', 'embarked', 'farewel...
# 182482  ['shocked', 'hear', 'priest', 'coming', 'new',...
# 182483  ['real', 'music', 'people', 'complaining', 'mi...
# 182484  ['bought', 'day', 'came', 'listening', 'non', ...
# 182485  ['mighty', 'juda', 'priest', 'released', 'grea...
# 182486  ['first', 'got', 'cd', 'bit', 'skeptical', 'wo...
# 182487  ['band', 'lke', 'juda', 'priest', 'going', 'fi...
# 182488  ['review', 'deluxe', 'version', 'albumfor', 'h...
# 182489  ['heavy', 'album', 'reference', 'occult', 'lyr...
# 182490  ['whoa', 'awesome', 'beat', 'expectation', 'da...
# 182491  ['juda', 'priest', 'simply', 'one', 'greatest'...
# 182492  ['suppose', 'put', 'obligatory', 'credential',...
# 182493  ['excellent', 'album', 'juda', 'priest', 'neve...
# 182494  ['awesome', 'new', 'album', 'juda', 'preist', ...
# 182495  ['first', 'huge', 'priest', 'fan', 'album', 'b...
# 182496  ['music', 'hard', 'classic', 'sorry', 'write',...
# 182497  ['back', 'strength', 'one', 'great', 'metal', ...
# 182498  ['juda', 'priest', 'last', 'appeared', 'form',...
# 182499  ['like', 'new', 'cd', 'nt', 'love', 'bought', ...
# 182500  ['redeemer', 'soul', 'feast', 'juda', 'priest'...
# 182501  ['maybe', 'since', 'screaming', 'vengeance', '...
# 182502  ['guy', 'true', 'king', 'metal', 'nothing', 'w...
#
#                                              conca_review  \
# 0        filmed first serial killer movie story serial...
# 1        feeling iconic piece filmmaking mirror previo...
# 2        title come chalk mark murderer placed beggar ...
# 3        film easily top fritz lang best film quite po...
# 4        dark disturbingly satirical humorous exactly ...
# 5        german expressionist film directed auteur fri...
# 6        watching story unfold found quite rollercoast...
# 7        nt know writing somewhere guess would imagine...
# 8        first criterion release ever seen say quite i...
# 9        famous fritz lang classic child murderer germ...
# 10       german blu ray complete version date however ...
# 11       picture add another superb guerdon well known...
# 12       one greatest german film ever made hitchcock ...
# 13       one suspenseful movie ever view directed grea...
# 14       criterion done right presenting classic fritz...
# 15       film beyond time enigmatic title could imagin...
# 16       film year old came also german movie came thr...
# 17       fan fritz lang fan murder film however lang f...
# 18       wait little nasty man black come little chopp...
# 19       chilling film child murderer terrifies berlin...
# 20       review justice criterion done frtitz lang cri...
# 21       critic historian believe early look film noir...
# 22       make man kill young child even nt know look h...
# 23       fritz lang feature young peter lorre psychoti...
# 24       extremely impressive movie difficult review p...
# 25       fritz lang said behind every crime story ever...
# 26       film historics consider best film maybe ever ...
# 27       film breathes gritty texture desperation post...
# 28       spoiler great story entire city going crazy f...
# 29       loved movie kid still remake would awesome gr...
# ...                                                   ...
# 182473   jack white get musician feel suppose artist e...
# 182474   fell love jack white work elephant white stri...
# 182475   excellent follow debut blunderbuss jack stell...
# 182476   jack white requiem thing right good way conta...
# 182477   step back solo debut blunderbuss jack white g...
# 182478   faulkner fantastic fantastic fast rhythm solo...
# 182479   well eat crow one many skeptical jp carrying ...
# 182480   admire band endurance longevity important pat...
# 182481   think many band embarked farewell tour actual...
# 182482   shocked hear priest coming new album child me...
# 182483   real music people complaining mix part seem l...
# 182484   bought day came listening non stop good halfo...
# 182485   mighty juda priest released great metal recor...
# 182486   first got cd bit skeptical wondering juda pri...
# 182487   band lke juda priest going find plethora song...
# 182488   review deluxe version albumfor heavy metal ba...
# 182489   heavy album reference occult lyric k k downin...
# 182490   whoa awesome beat expectation dare say better...
# 182491   juda priest simply one greatest metal band ti...
# 182492   suppose put obligatory credential priest fan ...
# 182493   excellent album juda priest never ever disapp...
# 182494   awesome new album juda preist plain awesome l...
# 182495   first huge priest fan album best worst effort...
# 182496   music hard classic sorry write opinion one tr...
# 182497   back strength one great metal band ever juda ...
# 182498   juda priest last appeared form metal fever dr...
# 182499   like new cd nt love bought mega edition since...
# 182500   redeemer soul feast juda priest heavy melodic...
# 182501   maybe since screaming vengeance least favorit...
# 182502   guy true king metal nothing wrong album got i...
#
#                      keyVector  keyphrases_indices_length  UserIndex  \
# 0                           []                          0       2353
# 1                         [12]                          1       5482
# 2                         [12]                          1        755
# 3                     [12, 33]                          2       4781
# 4                          [5]                          1       2466
# 5                           []                          0       3122
# 6                           []                          0       5302
# 7                           []                          0        757
# 8                         [12]                          1       2169
# 9                         [30]                          1       1857
# 10                          []                          0       2056
# 11                          []                          0        290
# 12                          []                          0       2138
# 13                        [29]                          1       3510
# 14                          []                          0       5660
# 15                        [30]                          1       1400
# 16                    [12, 37]                          2       3425
# 17                    [12, 29]                          2       2222
# 18                    [12, 17]                          2       2678
# 19                          []                          0       1869
# 20                          []                          0        600
# 21                        [12]                          1       4438
# 22                          []                          0       1453
# 23                        [29]                          1       5456
# 24                    [11, 29]                          2       2833
# 25                          []                          0       2271
# 26                          []                          0        386
# 27                          []                          0       1494
# 28                          []                          0        370
# 29                          []                          0       3898
# ...                        ...                        ...        ...
# 182473                      []                          0       4935
# 182474      [1, 2, 17, 20, 21]                          5       1815
# 182475                      []                          0       1958
# 182476                 [1, 20]                          2       2558
# 182477              [1, 2, 21]                          3       4177
# 182478                     [3]                          1       5253
# 182479              [1, 3, 38]                          3       2078
# 182480                     [3]                          1       4328
# 182481    [1, 2, 3, 9, 38, 39]                          6       3881
# 182482                 [3, 12]                          2       3437
# 182483             [3, 38, 39]                          3       1645
# 182484                      []                          0       4599
# 182485                  [1, 3]                          2        282
# 182486         [3, 21, 38, 39]                          4       5230
# 182487                  [1, 3]                          2       1085
# 182488               [1, 2, 3]                          3       2762
# 182489                      []                          0        274
# 182490                 [3, 12]                          2       3794
# 182491                     [3]                          1       5961
# 182492             [3, 38, 39]                          3        177
# 182493                  [1, 3]                          2        465
# 182494                     [3]                          1       5295
# 182495                     [3]                          1       4683
# 182496                     [1]                          1       5703
# 182497          [1, 3, 38, 39]                          4       4451
# 182498             [3, 20, 38]                          3       4177
# 182499                      []                          0       4418
# 182500                      []                          0        800
# 182501  [1, 2, 3, 4, 5, 9, 20]                          7       4332
# 182502                     [3]                          1       5029
#
#         ItemIndex  Binary
# 0               0       1
# 1               0       1
# 2               0       1
# 3               0       1
# 4               0       1
# 5               0       1
# 6               0       1
# 7               0       1
# 8               0       1
# 9               0       1
# 10              0       1
# 11              0       1
# 12              0       1
# 13              0       1
# 14              0       1
# 15              0       1
# 16              0       1
# 17              0       1
# 18              0       1
# 19              0       1
# 20              0       1
# 21              0       1
# 22              0       1
# 23              0       1
# 24              0       1
# 25              0       1
# 26              0       1
# 27              0       1
# 28              0       1
# 29              1       1
# ...           ...     ...
# 182473       4393       1
# 182474       4393       1
# 182475       4393       1
# 182476       4393       1
# 182477       4393       0
# 182478       4394       1
# 182479       4394       1
# 182480       4394       0
# 182481       4394       1
# 182482       4394       1
# 182483       4394       1
# 182484       4394       1
# 182485       4394       1
# 182486       4394       1
# 182487       4394       1
# 182488       4394       1
# 182489       4394       0
# 182490       4394       1
# 182491       4394       1
# 182492       4394       0
# 182493       4394       1
# 182494       4394       1
# 182495       4394       1
# 182496       4394       0
# 182497       4394       1
# 182498       4394       1
# 182499       4394       0
# 182500       4394       1
# 182501       4394       1
# 182502       4394       1
#
# [182503 rows x 13 columns]

# %%
keyphrase_index_list = cur_df[KEYPHRASE].values
keyphrase_index_flatten_list = [item for sublist in keyphrase_index_list for item in sublist]
keyphrase_index_flatten_list
# Out:
# [12,
#  12,
#  12,
#  33,
#  5,
#  12,
#  30,
#  29,
#  30,
#  12,
#  37,
#  12,
#  29,
#  12,
#  17,
#  12,
#  29,
#  11,
#  29,
#  12,
#  5,
#  12,
#  12,
#  18,
#  17,
#  12,
#  12,
#  12,
#  5,
#  12,
#  5,
#  5,
#  12,
#  5,
#  12,
#  5,
#  12,
#  5,
#  12,
#  30,
#  12,
#  11,
#  20,
#  37,
#  11,
#  17,
#  29,
#  4,
#  17,
#  29,
#  34,
#  20,
#  37,
#  30,
#  37,
#  12,
#  12,
#  5,
#  11,
#  17,
#  5,
#  12,
#  17,
#  29,
#  28,
#  12,
#  22,
#  30,
#  1,
#  17,
#  22,
#  22,
#  12,
#  12,
#  11,
#  5,
#  11,
#  22,
#  30,
#  37,
#  30,
#  37,
#  5,
#  13,
#  22,
#  29,
#  30,
#  12,
#  1,
#  8,
#  23,
#  21,
#  23,
#  1,
#  5,
#  8,
#  20,
#  23,
#  23,
#  1,
#  23,
#  1,
#  5,
#  11,
#  17,
#  20,
#  23,
#  27,
#  39,
#  1,
#  11,
#  22,
#  23,
#  23,
#  38,
#  1,
#  20,
#  23,
#  5,
#  21,
#  1,
#  23,
#  38,
#  11,
#  23,
#  20,
#  1,
#  20,
#  29,
#  23,
#  23,
#  21,
#  1,
#  18,
#  22,
#  1,
#  23,
#  29,
#  1,
#  1,
#  12,
#  18,
#  23,
#  25,
#  37,
#  38,
#  39,
#  1,
#  4,
#  12,
#  20,
#  23,
#  38,
#  39,
#  20,
#  1,
#  18,
#  23,
#  11,
#  1,
#  3,
#  5,
#  6,
#  11,
#  16,
#  20,
#  23,
#  31,
#  1,
#  11,
#  18,
#  20,
#  23,
#  5,
#  18,
#  22,
#  0,
#  5,
#  18,
#  4,
#  18,
#  22,
#  27,
#  38,
#  18,
#  5,
#  18,
#  18,
#  18,
#  11,
#  18,
#  22,
#  29,
#  2,
#  18,
#  2,
#  5,
#  22,
#  5,
#  22,
#  22,
#  1,
#  5,
#  23,
#  23,
#  21,
#  23,
#  1,
#  2,
#  20,
#  23,
#  39,
#  1,
#  3,
#  38,
#  39,
#  1,
#  1,
#  1,
#  27,
#  1,
#  4,
#  8,
#  9,
#  20,
#  25,
#  1,
#  38,
#  39,
#  1,
#  1,
#  4,
#  12,
#  27,
#  38,
#  39,
#  0,
#  4,
#  38,
#  39,
#  1,
#  1,
#  1,
#  20,
#  1,
#  2,
#  9,
#  1,
#  20,
#  1,
#  2,
#  5,
#  13,
#  20,
#  38,
#  39,
#  1,
#  2,
#  20,
#  39,
#  1,
#  3,
#  9,
#  1,
#  3,
#  9,
#  21,
#  1,
#  2,
#  4,
#  20,
#  38,
#  39,
#  1,
#  1,
#  3,
#  5,
#  9,
#  25,
#  28,
#  1,
#  4,
#  9,
#  25,
#  1,
#  9,
#  34,
#  37,
#  38,
#  39,
#  1,
#  2,
#  1,
#  1,
#  1,
#  1,
#  4,
#  14,
#  1,
#  1,
#  4,
#  8,
#  27,
#  28,
#  38,
#  39,
#  1,
#  2,
#  23,
#  25,
#  1,
#  2,
#  14,
#  21,
#  25,
#  1,
#  1,
#  1,
#  25,
#  1,
#  1,
#  4,
#  8,
#  14,
#  20,
#  28,
#  1,
#  9,
#  12,
#  25,
#  1,
#  3,
#  8,
#  1,
#  3,
#  19,
#  33,
#  5,
#  25,
#  34,
#  38,
#  39,
#  5,
#  39,
#  1,
#  2,
#  3,
#  4,
#  6,
#  9,
#  21,
#  23,
#  27,
#  28,
#  33,
#  38,
#  39,
#  38,
#  39,
#  1,
#  5,
#  1,
#  4,
#  28,
#  33,
#  38,
#  39,
#  1,
#  23,
#  23,
#  34,
#  38,
#  39,
#  1,
#  2,
#  30,
#  38,
#  1,
#  3,
#  9,
#  20,
#  28,
#  30,
#  36,
#  38,
#  39,
#  1,
#  3,
#  5,
#  9,
#  12,
#  27,
#  28,
#  34,
#  1,
#  38,
#  39,
#  23,
#  28,
#  1,
#  5,
#  33,
#  1,
#  4,
#  1,
#  12,
#  21,
#  30,
#  1,
#  2,
#  4,
#  6,
#  9,
#  18,
#  39,
#  1,
#  2,
#  3,
#  9,
#  12,
#  28,
#  33,
#  34,
#  38,
#  39,
#  23,
#  1,
#  1,
#  2,
#  1,
#  4,
#  9,
#  20,
#  38,
#  39,
#  1,
#  28,
#  2,
#  29,
#  1,
#  1,
#  4,
#  5,
#  12,
#  20,
#  21,
#  1,
#  20,
#  21,
#  38,
#  39,
#  11,
#  1,
#  39,
#  1,
#  5,
#  23,
#  33,
#  1,
#  1,
#  28,
#  33,
#  1,
#  33,
#  1,
#  1,
#  1,
#  21,
#  38,
#  12,
#  28,
#  30,
#  5,
#  5,
#  21,
#  1,
#  2,
#  4,
#  39,
#  1,
#  12,
#  33,
#  39,
#  38,
#  39,
#  1,
#  21,
#  21,
#  38,
#  38,
#  39,
#  1,
#  1,
#  9,
#  12,
#  33,
#  34,
#  38,
#  39,
#  38,
#  39,
#  1,
#  38,
#  39,
#  3,
#  39,
#  38,
#  39,
#  1,
#  3,
#  4,
#  8,
#  9,
#  23,
#  34,
#  38,
#  21,
#  1,
#  21,
#  5,
#  2,
#  21,
#  38,
#  39,
#  5,
#  23,
#  30,
#  5,
#  5,
#  20,
#  2,
#  4,
#  5,
#  21,
#  2,
#  21,
#  37,
#  38,
#  39,
#  4,
#  5,
#  19,
#  21,
#  34,
#  19,
#  20,
#  21,
#  32,
#  37,
#  5,
#  5,
#  14,
#  21,
#  12,
#  21,
#  20,
#  2,
#  21,
#  21,
#  37,
#  5,
#  12,
#  21,
#  37,
#  21,
#  37,
#  5,
#  21,
#  37,
#  2,
#  21,
#  1,
#  1,
#  2,
#  3,
#  9,
#  25,
#  30,
#  1,
#  1,
#  4,
#  5,
#  12,
#  23,
#  1,
#  3,
#  5,
#  38,
#  5,
#  25,
#  4,
#  1,
#  23,
#  1,
#  4,
#  15,
#  1,
#  4,
#  5,
#  9,
#  25,
#  1,
#  3,
#  4,
#  9,
#  3,
#  3,
#  38,
#  39,
#  1,
#  1,
#  3,
#  4,
#  9,
#  15,
#  36,
#  38,
#  39,
#  1,
#  1,
#  9,
#  33,
#  38,
#  39,
#  3,
#  1,
#  2,
#  3,
#  5,
#  22,
#  1,
#  9,
#  15,
#  1,
#  5,
#  9,
#  21,
#  25,
#  28,
#  1,
#  5,
#  9,
#  25,
#  1,
#  23,
#  1,
#  15,
#  25,
#  1,
#  15,
#  1,
#  1,
#  9,
#  1,
#  3,
#  1,
#  15,
#  1,
#  2,
#  4,
#  9,
#  12,
#  15,
#  34,
#  1,
#  2,
#  4,
#  5,
#  15,
#  28,
#  30,
#  38,
#  39,
#  1,
#  15,
#  19,
#  3,
#  1,
#  3,
#  15,
#  36,
#  1,
#  15,
#  1,
#  5,
#  9,
#  15,
#  1,
#  15,
#  1,
#  9,
#  19,
#  36,
#  1,
#  21,
#  1,
#  8,
#  23,
#  27,
#  33,
#  38,
#  39,
#  1,
#  12,
#  25,
#  38,
#  39,
#  1,
#  2,
#  5,
#  6,
#  27,
#  38,
#  5,
#  1,
#  33,
#  39,
#  1,
#  2,
#  6,
#  23,
#  33,
#  38,
#  39,
#  21,
#  1,
#  2,
#  5,
#  6,
#  9,
#  11,
#  14,
#  21,
#  25,
#  33,
#  34,
#  38,
#  39,
#  20,
#  38,
#  39,
#  38,
#  1,
#  2,
#  12,
#  21,
#  25,
#  30,
#  33,
#  38,
#  39,
#  1,
#  2,
#  5,
#  27,
#  33,
#  38,
#  30,
#  38,
#  39,
#  1,
#  2,
#  6,
#  21,
#  38,
#  39,
#  1,
#  38,
#  39,
#  1,
#  33,
#  19,
#  1,
#  33,
#  38,
#  39,
#  23,
#  1,
#  2,
#  38,
#  1,
#  21,
#  38,
#  39,
#  1,
#  29,
#  33,
#  38,
#  1,
#  5,
#  9,
#  38,
#  39,
#  38,
#  1,
#  25,
#  38,
#  39,
#  1,
#  2,
#  3,
#  6,
#  14,
#  20,
#  21,
#  25,
#  33,
#  38,
#  39,
#  1,
#  21,
#  38,
#  39,
#  1,
#  2,
#  38,
#  39,
#  1,
#  2,
#  6,
#  9,
#  11,
#  12,
#  14,
#  33,
#  38,
#  39,
#  1,
#  38,
#  1,
#  2,
#  21,
#  33,
#  38,
#  39,
#  4,
#  38,
#  21,
#  38,
#  1,
#  5,
#  6,
#  9,
#  14,
#  25,
#  28,
#  34,
#  38,
#  39,
#  3,
#  21,
#  38,
#  39,
#  3,
#  38,
#  2,
#  3,
#  14,
#  38,
#  1,
#  2,
#  3,
#  6,
#  9,
#  14,
#  20,
#  21,
#  27,
#  33,
#  35,
#  38,
#  39,
#  0,
#  2,
#  38,
#  1,
#  5,
#  6,
#  19,
#  20,
#  21,
#  34,
#  38,
#  1,
#  2,
#  3,
#  14,
#  33,
#  38,
#  39,
#  1,
#  2,
#  6,
#  21,
#  32,
#  34,
#  38,
#  39,
#  1,
#  2,
#  21,
#  39,
#  1,
#  2,
#  6,
#  21,
#  27,
#  38,
#  39,
#  38,
#  39,
#  14,
#  33,
#  39,
#  1,
#  1,
#  6,
#  14,
#  1,
#  6,
#  21,
#  38,
#  39,
#  5,
#  14,
#  20,
#  21,
#  23,
#  39,
#  11,
#  16,
#  18,
#  23,
#  23,
#  26,
#  38,
#  23,
#  23,
#  23,
#  39,
#  23,
#  23,
#  23,
#  25,
#  1,
#  39,
#  1,
#  12,
#  20,
#  23,
#  26,
#  38,
#  39,
#  1,
#  2,
#  20,
#  23,
#  38,
#  39,
#  1,
#  23,
#  12,
#  23,
#  1,
#  12,
#  23,
#  23,
#  1,
#  8,
#  12,
#  22,
#  23,
#  1,
#  17,
#  23,
#  1,
#  23,
#  38,
#  1,
#  23,
#  5,
#  1,
#  17,
#  1,
#  12,
#  23,
#  1,
#  23,
#  39,
#  1,
#  23,
#  38,
#  5,
#  17,
#  23,
#  38,
#  1,
#  23,
#  23,
#  1,
#  ...]

# %%
keyphrase_count = pd.DataFrame.from_dict({'keyphrase': keyphrase_index_flatten_list, 
                        'count': np.ones(len(keyphrase_index_flatten_list))}).groupby(['keyphrase'])['count'].sum().to_frame().reset_index().sort_values('count', ascending=False)
keyphrase_count = keyphrase_count.reset_index(drop=True).reset_index()

# %%
keyphrase_count['count'] = keyphrase_count['count'] / len(cur_df)
keyphrase_count
# Out:
#     index  keyphrase     count
# 0       0          1  0.340208
# 1       1          5  0.196972
# 2       2         12  0.126529
# 3       3          3  0.124749
# 4       4         38  0.116957
# 5       5          2  0.104119
# 6       6         20  0.101412
# 7       7         39  0.091456
# 8       8         21  0.091368
# 9       9         18  0.072585
# 10     10          4  0.064010
# 11     11          6  0.047413
# 12     12         30  0.047205
# 13     13         27  0.046690
# 14     14         28  0.042903
# 15     15         11  0.041736
# 16     16         13  0.041462
# 17     17          9  0.041090
# 18     18          0  0.041051
# 19     19         23  0.038290
# 20     20         25  0.029731
# 21     21         17  0.029419
# 22     22         19  0.027035
# 23     23         33  0.026772
# 24     24         34  0.023172
# 25     25          8  0.017233
# 26     26         29  0.016981
# 27     27         36  0.014876
# 28     28         14  0.014800
# 29     29         37  0.014652
# 30     30         31  0.013342
# 31     31         16  0.012159
# 32     32         24  0.010564
# 33     33         26  0.009485
# 34     34          7  0.008170
# 35     35         35  0.008164
# 36     36         22  0.007781
# 37     37         15  0.006942
# 38     38         32  0.006477
# 39     39         10  0.006427

# %%
# fig9 = plt.figure(figsize=(3, 3), dpi=100)
# ax9 = fig9.add_subplot(111)

# plt.rcParams["axes.labelsize"] = 8
sns.set_context("paper", rc={"font.size":8,"axes.titlesize":8,"axes.labelsize":8})  

fig, ax = plt.subplots(figsize=(4, 1.5), dpi=100)
ax = sns.barplot(x="index", y='count', data=keyphrase_count, color="white", edgecolor=".2")

# vals = ax.get_yticks()
# ax.set_yticklabels(['{:,.2%}'.format(x) for x in vals])

# ax.set_xlim(0,40)
# ax.set_ylim(0,0.4)

import matplotlib.ticker as ticker
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
# ax.set_xlim(1,40)
# ax.set_xticks(range(1,40,5))

ax.set_xlabel("CDs&Vinyl Key Phrases Index")
ax.set_ylabel("key phrase\ncoverage")
# legend = plt.legend(loc='upper right', shadow=True, fontsize=10)
# legend = plt.legend(shadow=True, fontsize=10)
handles, labels = ax.get_legend_handles_labels()
plt.tight_layout()
fig_path = '../figs'
name = 'CDsVinyl_keyphrase_coverage'
fig.savefig('{0}/{1}.pdf'.format(fig_path, name), bbox_inches="tight", pad_inches=0, format='pdf')

# %% [markdown]
# # Beer Dataset

# %%
train_df = pd.read_csv('../data/beer/Train.csv')
valid_df = pd.read_csv('../data/beer/Valid.csv')
test_df = pd.read_csv('../data/beer/Test.csv')

cur_df = train_df.append(valid_df).append(test_df)

cur_df['review/text'] = cur_df['review/text'].astype('str')
cur_df[KEYPHRASE] = cur_df[KEYPHRASE].apply(lambda key: ast.literal_eval(key))
cur_df
# Out:
# /home/kai/.local/lib/python3.6/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#         Binary  ItemIndex  Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0            0        659           0             0               0
# 1            0        659           1             1               1
# 2            0        659           2             2               2
# 3            1        659           3             3               3
# 4            1        659           4             4               4
# 5            0        659           5             5               5
# 6            0        659           6             6               6
# 7            0        659           7             7               7
# 8            0        659           8             8               8
# 9            1        659           9             9               9
# 10           1        659          10            10              10
# 11           0        659          11            11              11
# 12           0        659          12            12              12
# 13           0        659          13            13              13
# 14           0        659          14            14              14
# 15           0        659          15            15              15
# 16           0        659          16            16              16
# 17           0        659          17            17              17
# 18           0        659          18            18              18
# 19           0        659          19            19              19
# 20           1        659          20            20              20
# 21           1        659          21            21              21
# 22           1        659          22            22              22
# 23           1        659          23            23              23
# 24           0        659          24            24              24
# 25           0        659          25            25              25
# 26           1        659          26            26              26
# 27           0        659          27            27              27
# 28           0        659          28            28              28
# 29           0        659          29            29              29
# ...        ...        ...         ...           ...             ...
# 200516       0        486        6367        987738          987738
# 200517       1       1537        6367        423249          423249
# 200518       0       2744        6368        372925          372925
# 200519       0       3542        6368        885415          885415
# 200520       0       1394        6368        865977          865977
# 200521       0        186        6368        919201          919201
# 200522       0        323        6368        964420          964420
# 200523       0       2039        6368        903943          903943
# 200524       0        486        6368        987735          987735
# 200525       0       2125        6368        518167          518167
# 200526       1        226        6368        611118          611118
# 200527       0       1056        6368        699302          699302
# 200528       1        742        6368        178741          178741
# 200529       0       1360        6368        889863          889863
# 200530       0        542        6368         72617           72617
# 200531       0        543        6369        469368          469368
# 200532       0       2953        6369        866826          866826
# 200533       0       3165        6369        275850          275850
# 200534       1       3143        6369        638321          638321
# 200535       1       3621        6369        239736          239736
# 200536       0       2567        6369        743682          743682
# 200537       0       1881        6369        737585          737585
# 200538       1       2701        6369        226790          226790
# 200539       0        322        6369        902516          902516
# 200540       0       2755        6369        574568          574568
# 200541       0       1871        6369        768938          768938
# 200542       0       1865        6369        693413          693413
# 200543       1       1521        6369       1017559         1017559
# 200544       0       2988        6369        191272          191272
# 200545       0       1883        6369        735718          735718
#
#         Unnamed: 1  UserIndex  beer/ABV  \
# 0              NaN       1767       5.5
# 1              NaN       6159       5.5
# 2              NaN       3516       5.5
# 3              NaN       2893       5.5
# 4              NaN       4858       5.5
# 5              NaN       4924       5.5
# 6              NaN       4106       5.5
# 7              NaN       2844       5.5
# 8              NaN       2197       5.5
# 9              NaN       1044       5.5
# 10             NaN       1881       5.5
# 11             NaN       1181       5.5
# 12             NaN       1029       5.5
# 13             NaN       6349       5.5
# 14             NaN       2767       5.5
# 15             NaN       6221       5.5
# 16             NaN       2962       5.5
# 17             NaN       3044       5.5
# 18             NaN       3764       5.5
# 19             NaN       1707       5.5
# 20             NaN       1140       5.5
# 21             NaN       3661       5.5
# 22             NaN       5039       5.5
# 23             NaN       4839       5.5
# 24             NaN       3121       5.5
# 25             NaN       1289       5.5
# 26             NaN       2942       5.5
# 27             NaN       1420       5.5
# 28             NaN        636       5.5
# 29             NaN       2993       5.5
# ...            ...        ...       ...
# 200516    899621.0       6367       5.3
# 200517    389022.0       6367       4.2
# 200518    339699.0       6368       5.0
# 200519    805163.0       6368       5.0
# 200520    788413.0       6368       5.0
# 200521    837270.0       6368       4.9
# 200522    877009.0       6368       4.1
# 200523    822823.0       6368       5.2
# 200524    899618.0       6368       5.3
# 200525    476605.0       6368       4.0
# 200526    563103.0       6368       7.2
# 200527    636848.0       6368       6.5
# 200528    162334.0       6368       7.0
# 200529    809506.0       6368       5.0
# 200530     61972.0       6368       4.7
# 200531    431408.0       6369       5.3
# 200532    789262.0       6369       4.5
# 200533    249631.0       6369       4.2
# 200534    583717.0       6369       5.9
# 200535    219509.0       6369       4.7
# 200536    677088.0       6369       6.1
# 200537    671715.0       6369       4.9
# 200538    207509.0       6369       4.9
# 200539    821492.0       6369       5.4
# 200540    529855.0       6369       5.5
# 200541    701497.0       6369       6.0
# 200542    631331.0       6369       6.6
# 200543    927989.0       6369       4.5
# 200544    173468.0       6369       7.1
# 200545    669848.0       6369       4.9
#
#                                       beer/name  \
# 0                              Caldera Pale Ale
# 1                              Caldera Pale Ale
# 2                              Caldera Pale Ale
# 3                              Caldera Pale Ale
# 4                              Caldera Pale Ale
# 5                              Caldera Pale Ale
# 6                              Caldera Pale Ale
# 7                              Caldera Pale Ale
# 8                              Caldera Pale Ale
# 9                              Caldera Pale Ale
# 10                             Caldera Pale Ale
# 11                             Caldera Pale Ale
# 12                             Caldera Pale Ale
# 13                             Caldera Pale Ale
# 14                             Caldera Pale Ale
# 15                             Caldera Pale Ale
# 16                             Caldera Pale Ale
# 17                             Caldera Pale Ale
# 18                             Caldera Pale Ale
# 19                             Caldera Pale Ale
# 20                             Caldera Pale Ale
# 21                             Caldera Pale Ale
# 22                             Caldera Pale Ale
# 23                             Caldera Pale Ale
# 24                             Caldera Pale Ale
# 25                             Caldera Pale Ale
# 26                             Caldera Pale Ale
# 27                             Caldera Pale Ale
# 28                             Caldera Pale Ale
# 29                             Caldera Pale Ale
# ...                                         ...
# 200516                      Black Toad Dark Ale
# 200517                             Honker's Ale
# 200518  Samuel Smith's, The Famous Taddy Porter
# 200519                  Wexford Irish Cream Ale
# 200520                               Harp Lager
# 200521                        Anchor Steam Beer
# 200522                      Beamish Irish Stout
# 200523                      Michelob Amber Bock
# 200524                      Black Toad Dark Ale
# 200525                     Murphy's Irish Stout
# 200526                     Arrogant Bastard Ale
# 200527              Ebulum Elderberry Black Ale
# 200528                    Chimay Première (Red)
# 200529                    Grolsch Premium Lager
# 200530                      Boddingtons Pub Ale
# 200531                                  Bohemia
# 200532                              Smithwick's
# 200533                 Strawberry Harvest Lager
# 200534                      Stone Smoked Porter
# 200535                         Xingu Black Beer
# 200536                             Red Tail Ale
# 200537                        Leinenkugel's Red
# 200538                 Samuel Adams Cream Stout
# 200539                     Beach Bum Blonde Ale
# 200540                 Saranac Adirondack Lager
# 200541                     Left Hand Milk Stout
# 200542                             Leffe Blonde
# 200543                              Hocus Pocus
# 200544                            Snake Dog IPA
# 200545               Leinenkugel's Sunset Wheat
#
#                                  beer/style  \
# 0                   American Pale Ale (APA)
# 1                   American Pale Ale (APA)
# 2                   American Pale Ale (APA)
# 3                   American Pale Ale (APA)
# 4                   American Pale Ale (APA)
# 5                   American Pale Ale (APA)
# 6                   American Pale Ale (APA)
# 7                   American Pale Ale (APA)
# 8                   American Pale Ale (APA)
# 9                   American Pale Ale (APA)
# 10                  American Pale Ale (APA)
# 11                  American Pale Ale (APA)
# 12                  American Pale Ale (APA)
# 13                  American Pale Ale (APA)
# 14                  American Pale Ale (APA)
# 15                  American Pale Ale (APA)
# 16                  American Pale Ale (APA)
# 17                  American Pale Ale (APA)
# 18                  American Pale Ale (APA)
# 19                  American Pale Ale (APA)
# 20                  American Pale Ale (APA)
# 21                  American Pale Ale (APA)
# 22                  American Pale Ale (APA)
# 23                  American Pale Ale (APA)
# 24                  American Pale Ale (APA)
# 25                  American Pale Ale (APA)
# 26                  American Pale Ale (APA)
# 27                  American Pale Ale (APA)
# 28                  American Pale Ale (APA)
# 29                  American Pale Ale (APA)
# ...                                     ...
# 200516                    English Brown Ale
# 200517                       English Bitter
# 200518                       English Porter
# 200519                            Cream Ale
# 200520                      Euro Pale Lager
# 200521       California Common / Steam Beer
# 200522                      Irish Dry Stout
# 200523                                 Bock
# 200524                    English Brown Ale
# 200525                      Irish Dry Stout
# 200526                  American Strong Ale
# 200527  Scottish Gruit / Ancient Herbed Ale
# 200528                               Dubbel
# 200529                      Euro Pale Lager
# 200530                     English Pale Ale
# 200531                      German Pilsener
# 200532                        Irish Red Ale
# 200533               Fruit / Vegetable Beer
# 200534                      American Porter
# 200535                          Schwarzbier
# 200536             American Amber / Red Ale
# 200537                         Vienna Lager
# 200538                   Milk / Sweet Stout
# 200539                  American Blonde Ale
# 200540                      German Pilsener
# 200541                   Milk / Sweet Stout
# 200542                     Belgian Pale Ale
# 200543              American Pale Wheat Ale
# 200544                         American IPA
# 200545                              Witbier
#
#                                              conca_review  \
# 0        caldera pale ale picked grape gourmet vb ligh...
# 1        oz poured pint glass really like beer like pa...
# 2        pours cloudy orange crisp white two finger he...
# 3        received beer powerball really sorry nt know ...
# 4        bought beersofeurope com poured golden yellow...
# 5        received one bif recently first thing grabbed...
# 6        orangeish peach head smell hoppy taste hoppy ...
# 7        poured clear pint glass freshness date single...
# 8        wish flavor bore strength aroma still bad bee...
# 9        really enjoying variety quality brew finding ...
# 10       oz poured tulip see thru deep gold body finge...
# 11       pours deep shade gold fluffy ecru head aroma ...
# 12       pours clear golden color slight orange hue on...
# 13       poured clear orange color gold highlight foam...
# 14       oz liquid solution pale ale appropriately pal...
# 15       poured pint glass reminiscent pilsner apa fin...
# 16       pours pale straw gold frothy light finger hea...
# 17       pours crisp clear pale gold color small head ...
# 18       grabbed single state line clear light orange ...
# 19       poured clear golden hue two finger bright whi...
# 20       pours clear gold amber hue three finger white...
# 21       pours crystal clear light golden hue lemon st...
# 22       poured pint glass pours clear golden color on...
# 23       thanks thirstyhophead introduced pleasure cal...
# 24       clear golden colored ale capped one finger of...
# 25       new beer tidewater virginia area grape gourme...
# 26       pours pale straw like color bubbly finger dee...
# 27       oz pint glass pours clear gold several finger...
# 28       beer run charlottesville va enjoyed site supe...
# 29       pours pale golden hue substantial fluffy head...
# ...                                                   ...
# 200516   fairly light porter much head lacing pleasant...
# 200517   layover chicago midway airport happy see beer...
# 200518   porter pours nice deep coffee brown light bei...
# 200519   ale pours nice bronze amber nice mocha colore...
# 200520   good general lager pours pale gold bit darker...
# 200521   recommended quite happy pours dark amber litt...
# 200522   excellent stout pours deep dark chocolatey br...
# 200523   off tap yield decent dark amber loses head qu...
# 200524   ale pours dark near stout color nice head lac...
# 200525   stout one favorite pours well dark near black...
# 200526   strong solid ale strong dark copper red poir ...
# 200527   found one knew try poirs darkih red dense tan...
# 200528   pours deep dark good solid offwhite head reta...
# 200529   lager pours golden amber white head little he...
# 200530   excellent readily available pale ale pop top ...
# 200531   slight hop aroma nice hop flavor nt quite exp...
# 200532   overall beer worth trying bottom line front l...
# 200533   smell like strawberry little much obviously m...
# 200534   must try smoked beer one one best far dark co...
# 200535   interesting beer homebrewer one type beer hop...
# 200536   beer nice roasty malty smell bottle got came ...
# 200537   beer pretty good overall think another review...
# 200538   excellent brew sam adam impressed maybe surpr...
# 200539   look like ab intimidated micro brew market se...
# 200540   pours deep yelloww amber color nice offwhite ...
# 200541   proof american make good stout great example ...
# 200542   great belgian ale hard find decent aroma yell...
# 200543   one pours light straw color hint haziness nic...
# 200544   expected little flying dog ipa enjoyed pale a...
# 200545   interesting beer beer pours deep golden color...
#
#                                                 keyVector  \
# 0          [1, 7, 12, 14, 16, 29, 31, 34, 39, 40, 42, 45]
# 1                 [1, 16, 18, 20, 24, 39, 42, 43, 45, 55]
# 2                                        [12, 36, 39, 42]
# 3                                                [12, 42]
# 4       [1, 5, 7, 12, 14, 16, 18, 19, 26, 31, 34, 40, ...
# 5                                [10, 12, 16, 31, 36, 42]
# 6                                                    [39]
# 7               [0, 1, 3, 12, 14, 16, 18, 19, 34, 39, 43]
# 8                         [3, 10, 16, 18, 26, 36, 43, 51]
# 9                  [1, 9, 14, 20, 32, 36, 42, 43, 45, 55]
# 10      [1, 7, 12, 14, 16, 19, 31, 34, 36, 39, 41, 43,...
# 11                                 [1, 7, 14, 29, 34, 45]
# 12                                    [1, 12, 39, 42, 45]
# 13                         [2, 4, 16, 21, 26, 39, 42, 45]
# 14                         [1, 5, 12, 26, 39, 40, 45, 51]
# 15                            [5, 12, 14, 16, 34, 40, 42]
# 16                                   [11, 12, 16, 31, 45]
# 17                     [2, 7, 12, 16, 31, 36, 37, 45, 55]
# 18                 [1, 7, 12, 14, 16, 19, 31, 34, 39, 41]
# 19                                    [7, 16, 30, 42, 45]
# 20      [1, 2, 4, 5, 10, 12, 16, 18, 19, 21, 26, 29, 3...
# 21      [1, 2, 11, 12, 14, 16, 21, 26, 31, 34, 39, 40,...
# 22         [2, 4, 12, 14, 18, 21, 34, 36, 39, 40, 41, 45]
# 23                                                   [51]
# 24                            [1, 10, 12, 16, 19, 41, 45]
# 25                                    [3, 18, 36, 42, 52]
# 26                  [1, 2, 7, 16, 18, 20, 31, 36, 42, 43]
# 27              [2, 4, 5, 12, 16, 18, 21, 29, 33, 45, 55]
# 28      [0, 1, 3, 7, 11, 12, 14, 16, 21, 26, 29, 32, 4...
# 29                             [1, 5, 16, 18, 21, 43, 45]
# ...                                                   ...
# 200516                                                [0]
# 200517                                                [1]
# 200518                          [1, 5, 8, 20, 27, 44, 46]
# 200519                                    [1, 16, 48, 55]
# 200520                                    [1, 10, 45, 55]
# 200521                                               [38]
# 200522                              [2, 6, 8, 43, 44, 50]
# 200523                                           [30, 52]
# 200524                                         [0, 6, 52]
# 200525                      [0, 6, 8, 10, 22, 43, 44, 50]
# 200526                                [1, 12, 43, 47, 58]
# 200527                             [1, 6, 43, 55, 58, 64]
# 200528                            [1, 14, 21, 41, 54, 65]
# 200529                                    [1, 16, 42, 45]
# 200530                                               [36]
# 200531                                               [12]
# 200532                           [11, 22, 30, 44, 51, 58]
# 200533                                           [55, 64]
# 200534                                        [0, 22, 55]
# 200535                                        [1, 30, 55]
# 200536                                        [0, 16, 42]
# 200537                                [4, 16, 39, 42, 58]
# 200538                                 [0, 1, 11, 16, 30]
# 200539                                       [12, 30, 39]
# 200540                                 [1, 7, 11, 41, 51]
# 200541                                  [0, 1, 8, 16, 41]
# 200542                                       [11, 51, 65]
# 200543                                               [42]
# 200544                                               [11]
# 200545               [12, 16, 30, 39, 40, 42, 45, 64, 69]
#
#         keyphrases_indices_length  \
# 0                              12
# 1                              10
# 2                               4
# 3                               2
# 4                              18
# 5                               6
# 6                               1
# 7                              11
# 8                               8
# 9                              10
# 10                             14
# 11                              6
# 12                              5
# 13                              8
# 14                              8
# 15                              7
# 16                              5
# 17                              9
# 18                             10
# 19                              5
# 20                             17
# 21                             15
# 22                             12
# 23                              1
# 24                              7
# 25                              5
# 26                             10
# 27                             11
# 28                             17
# 29                              7
# ...                           ...
# 200516                          1
# 200517                          1
# 200518                          7
# 200519                          4
# 200520                          4
# 200521                          1
# 200522                          6
# 200523                          2
# 200524                          3
# 200525                          8
# 200526                          5
# 200527                          6
# 200528                          6
# 200529                          4
# 200530                          1
# 200531                          1
# 200532                          6
# 200533                          2
# 200534                          3
# 200535                          3
# 200536                          3
# 200537                          5
# 200538                          5
# 200539                          3
# 200540                          5
# 200541                          5
# 200542                          3
# 200543                          1
# 200544                          1
# 200545                          9
#
#                                                    review  review/overall  \
# 0       ['caldera', 'pale', 'ale', 'picked', 'grape', ...             4.0
# 1       ['oz', 'poured', 'pint', 'glass', 'really', 'l...             2.5
# 2       ['pours', 'cloudy', 'orange', 'crisp', 'white'...             4.0
# 3       ['received', 'beer', 'powerball', 'really', 's...             4.5
# 4       ['bought', 'beersofeurope', 'com', 'poured', '...             4.5
# 5       ['received', 'one', 'bif', 'recently', 'first'...             4.0
# 6       ['orangeish', 'peach', 'head', 'smell', 'hoppy...             4.0
# 7       ['poured', 'clear', 'pint', 'glass', 'freshnes...             3.5
# 8       ['wish', 'flavor', 'bore', 'strength', 'aroma'...             3.5
# 9       ['really', 'enjoying', 'variety', 'quality', '...             5.0
# 10      ['oz', 'poured', 'tulip', 'see', 'thru', 'deep...             4.5
# 11      ['pours', 'deep', 'shade', 'gold', 'fluffy', '...             4.0
# 12      ['pours', 'clear', 'golden', 'color', 'slight'...             4.0
# 13      ['poured', 'clear', 'orange', 'color', 'gold',...             4.0
# 14      ['oz', 'liquid', 'solution', 'pale', 'ale', 'a...             4.0
# 15      ['poured', 'pint', 'glass', 'reminiscent', 'pi...             4.0
# 16      ['pours', 'pale', 'straw', 'gold', 'frothy', '...             3.5
# 17      ['pours', 'crisp', 'clear', 'pale', 'gold', 'c...             4.0
# 18      ['grabbed', 'single', 'state', 'line', 'clear'...             4.0
# 19      ['poured', 'clear', 'golden', 'hue', 'two', 'f...             3.5
# 20      ['pours', 'clear', 'gold', 'amber', 'hue', 'th...             4.5
# 21      ['pours', 'crystal', 'clear', 'light', 'golden...             4.5
# 22      ['poured', 'pint', 'glass', 'pours', 'clear', ...             5.0
# 23      ['thanks', 'thirstyhophead', 'introduced', 'pl...             5.0
# 24      ['clear', 'golden', 'colored', 'ale', 'capped'...             3.5
# 25      ['new', 'beer', 'tidewater', 'virginia', 'area...             4.0
# 26      ['pours', 'pale', 'straw', 'like', 'color', 'b...             4.5
# 27      ['oz', 'pint', 'glass', 'pours', 'clear', 'gol...             4.0
# 28      ['beer', 'run', 'charlottesville', 'va', 'enjo...             4.0
# 29      ['pours', 'pale', 'golden', 'hue', 'substantia...             3.5
# ...                                                   ...             ...
# 200516  ['fairly', 'light', 'porter', 'much', 'head', ...             3.0
# 200517  ['layover', 'chicago', 'midway', 'airport', 'h...             4.5
# 200518  ['porter', 'pours', 'nice', 'deep', 'coffee', ...             3.0
# 200519  ['ale', 'pours', 'nice', 'bronze', 'amber', 'n...             4.0
# 200520  ['good', 'general', 'lager', 'pours', 'pale', ...             3.5
# 200521  ['recommended', 'quite', 'happy', 'pours', 'da...             4.0
# 200522  ['excellent', 'stout', 'pours', 'deep', 'dark'...             4.0
# 200523  ['off', 'tap', 'yield', 'decent', 'dark', 'amb...             2.0
# 200524  ['ale', 'pours', 'dark', 'near', 'stout', 'col...             4.0
# 200525  ['stout', 'one', 'favorite', 'pours', 'well', ...             3.5
# 200526  ['strong', 'solid', 'ale', 'strong', 'dark', '...             4.5
# 200527  ['found', 'one', 'knew', 'try', 'poirs', 'dark...             4.0
# 200528  ['pours', 'deep', 'dark', 'good', 'solid', 'of...             4.5
# 200529  ['lager', 'pours', 'golden', 'amber', 'white',...             4.0
# 200530  ['excellent', 'readily', 'available', 'pale', ...             4.0
# 200531  ['slight', 'hop', 'aroma', 'nice', 'hop', 'fla...             3.5
# 200532  ['overall', 'beer', 'worth', 'trying', 'bottom...             4.0
# 200533  ['smell', 'like', 'strawberry', 'little', 'muc...             3.5
# 200534  ['must', 'try', 'smoked', 'beer', 'one', 'one'...             4.5
# 200535  ['interesting', 'beer', 'homebrewer', 'one', '...             4.5
# 200536  ['beer', 'nice', 'roasty', 'malty', 'smell', '...             3.0
# 200537  ['beer', 'pretty', 'good', 'overall', 'think',...             4.0
# 200538  ['excellent', 'brew', 'sam', 'adam', 'impresse...             5.0
# 200539  ['look', 'like', 'ab', 'intimidated', 'micro',...             4.0
# 200540  ['pours', 'deep', 'yelloww', 'amber', 'color',...             3.5
# 200541  ['proof', 'american', 'make', 'good', 'stout',...             4.0
# 200542  ['great', 'belgian', 'ale', 'hard', 'find', 'd...             3.0
# 200543  ['one', 'pours', 'light', 'straw', 'color', 'h...             4.5
# 200544  ['expected', 'little', 'flying', 'dog', 'ipa',...             3.5
# 200545  ['interesting', 'beer', 'beer', 'pours', 'deep...             3.5
#
#                                               review/text  review/timeUnix  \
# 0       Caldera- Pale Ale\t\tPicked up at Grape & Gour...       1251327677
# 1       12 oz. can poured into a pint glass. I really ...       1250928902
# 2       A: Pours a cloudy orange with a crisp white tw...       1249866208
# 3       Received this can through Beer Powerball. I am...       1249847121
# 4       355ml can bought from Beersofeurope.com...\t\t...       1249556277
# 5       I received this one in a BIF recently and it w...       1249347819
# 6       Orangeish with a peach head. Smell was hoppy. ...       1248223105
# 7       Poured from 12oz can into a clear pint glass. ...       1248142715
# 8       I wish the flavor bore out the strength of the...       1247611689
# 9       I'm really enjoying the variety of quality bre...       1246913078
# 10      12 oz. can, poured into a tulip.\t\tSee-thru d...       1246835039
# 11      Pours a deep shade of gold with a fluffy ecru ...       1245632401
# 12      Pours a clear golden color with a slight orang...       1245007399
# 13      A - Poured out a clear, orange color with gold...       1243386855
# 14      A 12 oz can from Liquid Solutions.\t\tA: The p...       1243111472
# 15      Poured into pint glass.\t\tA - reminiscent of ...       1242695740
# 16      Pours a pale straw gold with a frothy light 2 ...       1242591041
# 17      Pours a crisp clear pale gold color with a sma...       1240194272
# 18      Grabbed a single at State Line\t\tA: Clear lig...       1239404031
# 19      Poured from the can a clear golden hue with tw...       1238806680
# 20      Pours a clear gold with some amber hues. Three...       1238102425
# 21      pours a crystal-clear light golden hue with le...       1237995185
# 22      Poured from a can into a pint glass.\t\tA: Pou...       1235940573
# 23      Thanks to thirstyhophead, who introduced me to...       1235869779
# 24      a: clear golden colored ale capped by a one-fi...       1235799776
# 25      A new beer for the Tidewater Virginia area, Gr...       1234402493
# 26      Pours out a pale straw like color with a bubbl...       1234301164
# 27      12 oz can into a pint glass. \t\tPours a clear...       1234289072
# 28      Can from Beer Run, Charlottesville, VA, enjoye...       1233532055
# 29      Pours a pale golden hue with a substantial flu...       1233527792
# ...                                                   ...              ...
# 200516  A fairly light porter with not much head or la...       1160021367
# 200517  During a layover in the Chicago Midway airport...       1159899811
# 200518  The porter pours a nice deep coffee brown, wit...       1166407595
# 200519  This ale pours a nice bronze amber, with nice ...       1166395869
# 200520  The is a good general lager, and it pours a pa...       1166675114
# 200521  This was recommended to me and I was quite hap...       1168229903
# 200522  This is an excellent stout. It pours a deep da...       1166673770
# 200523  Off tap this yields a decent dark amber, but l...       1166407989
# 200524  This ale pours a very dark, near stout, color ...       1168230085
# 200525  This stout is one of my favorites and it pours...       1166669636
# 200526  This is a strong solid ale that is strong. Dar...       1166678688
# 200527  I found this one and knew I had to try it. It ...       1166828343
# 200528  This pours an deep dark with a good solid off ...       1172005555
# 200529  This lager pours a golden amber with a white h...       1168024283
# 200530  Excellent readily available pale ale. Pop the ...       1166225318
# 200531  Slight hop aroma, but nice hop flavor. Didn't ...       1179103363
# 200532  Overall a beer very worth trying. The bottom l...       1158451337
# 200533  Smells like strawberry, but a little too much-...       1208820172
# 200534  This is a must try. I've only had a few smoked...       1203296675
# 200535  This is a very interesting beer. As a homebrew...       1170550376
# 200536  This beer has a nice roasty malty smell to it....       1178149044
# 200537  This beer is pretty good. Overall I think anot...       1170638745
# 200538  Excellent brew from Sam Adams. I was very impr...       1169603467
# 200539  Looks like AB is intimidated by the micro brew...       1180481723
# 200540  Pours a deep yellow amber color with a nice of...       1214945053
# 200541  Proof that Americans can make a good stout. Th...       1180907462
# 200542  Great Belgian ale that is not too hard to find...       1180328597
# 200543  This one pours a very light straw color with a...       1217374928
# 200544  I expected a little more from Flying Dog with ...       1177192409
# 200545  What an interesting beer. This beer pours a de...       1183840907
#
#        user/profileName
# 0            NJpadreFan
# 1                 vacax
# 2              d0ggnate
# 3            babyhobbes
# 4               mdagnew
# 5           mikesgroove
# 6                 hdofu
# 7                argock
# 8              Seanibus
# 9       GratefulBeerGuy
# 10              PDXHops
# 11       IMincedTheKing
# 12              Goliath
# 13               zeff80
# 14              akorsak
# 15              wchesak
# 16             beer2day
# 17             bfields4
# 18                 dyan
# 19          Monkeyknife
# 20             HopDerek
# 21         djeucalyptus
# 22              mtrentm
# 23            maximum12
# 24              blackie
# 25               JayQue
# 26              bbothen
# 27             Kegatron
# 28           CrellMoset
# 29            beerman21
# ...                 ...
# 200516     zuffenhausen
# 200517     zuffenhausen
# 200518           zuggy9
# 200519           zuggy9
# 200520           zuggy9
# 200521           zuggy9
# 200522           zuggy9
# 200523           zuggy9
# 200524           zuggy9
# 200525           zuggy9
# 200526           zuggy9
# 200527           zuggy9
# 200528           zuggy9
# 200529           zuggy9
# 200530           zuggy9
# 200531      zymurgy4all
# 200532      zymurgy4all
# 200533      zymurgy4all
# 200534      zymurgy4all
# 200535      zymurgy4all
# 200536      zymurgy4all
# 200537      zymurgy4all
# 200538      zymurgy4all
# 200539      zymurgy4all
# 200540      zymurgy4all
# 200541      zymurgy4all
# 200542      zymurgy4all
# 200543      zymurgy4all
# 200544      zymurgy4all
# 200545      zymurgy4all
#
# [1002769 rows x 18 columns]

# %%
keyphrase_index_list = cur_df[KEYPHRASE].values
keyphrase_index_flatten_list = [item for sublist in keyphrase_index_list for item in sublist]
keyphrase_index_flatten_list
# Out:
# [1,
#  7,
#  12,
#  14,
#  16,
#  29,
#  31,
#  34,
#  39,
#  40,
#  42,
#  45,
#  1,
#  16,
#  18,
#  20,
#  24,
#  39,
#  42,
#  43,
#  45,
#  55,
#  12,
#  36,
#  39,
#  42,
#  12,
#  42,
#  1,
#  5,
#  7,
#  12,
#  14,
#  16,
#  18,
#  19,
#  26,
#  31,
#  34,
#  40,
#  42,
#  45,
#  51,
#  55,
#  68,
#  74,
#  10,
#  12,
#  16,
#  31,
#  36,
#  42,
#  39,
#  0,
#  1,
#  3,
#  12,
#  14,
#  16,
#  18,
#  19,
#  34,
#  39,
#  43,
#  3,
#  10,
#  16,
#  18,
#  26,
#  36,
#  43,
#  51,
#  1,
#  9,
#  14,
#  20,
#  32,
#  36,
#  42,
#  43,
#  45,
#  55,
#  1,
#  7,
#  12,
#  14,
#  16,
#  19,
#  31,
#  34,
#  36,
#  39,
#  41,
#  43,
#  45,
#  61,
#  1,
#  7,
#  14,
#  29,
#  34,
#  45,
#  1,
#  12,
#  39,
#  42,
#  45,
#  2,
#  4,
#  16,
#  21,
#  26,
#  39,
#  42,
#  45,
#  1,
#  5,
#  12,
#  26,
#  39,
#  40,
#  45,
#  51,
#  5,
#  12,
#  14,
#  16,
#  34,
#  40,
#  42,
#  11,
#  12,
#  16,
#  31,
#  45,
#  2,
#  7,
#  12,
#  16,
#  31,
#  36,
#  37,
#  45,
#  55,
#  1,
#  7,
#  12,
#  14,
#  16,
#  19,
#  31,
#  34,
#  39,
#  41,
#  7,
#  16,
#  30,
#  42,
#  45,
#  1,
#  2,
#  4,
#  5,
#  10,
#  12,
#  16,
#  18,
#  19,
#  21,
#  26,
#  29,
#  36,
#  42,
#  45,
#  52,
#  55,
#  1,
#  2,
#  11,
#  12,
#  14,
#  16,
#  21,
#  26,
#  31,
#  34,
#  39,
#  40,
#  45,
#  55,
#  68,
#  2,
#  4,
#  12,
#  14,
#  18,
#  21,
#  34,
#  36,
#  39,
#  40,
#  41,
#  45,
#  51,
#  1,
#  10,
#  12,
#  16,
#  19,
#  41,
#  45,
#  3,
#  18,
#  36,
#  42,
#  52,
#  1,
#  2,
#  7,
#  16,
#  18,
#  20,
#  31,
#  36,
#  42,
#  43,
#  2,
#  4,
#  5,
#  12,
#  16,
#  18,
#  21,
#  29,
#  33,
#  45,
#  55,
#  0,
#  1,
#  3,
#  7,
#  11,
#  12,
#  14,
#  16,
#  21,
#  26,
#  29,
#  32,
#  43,
#  45,
#  51,
#  55,
#  68,
#  1,
#  5,
#  16,
#  18,
#  21,
#  43,
#  45,
#  1,
#  5,
#  7,
#  10,
#  12,
#  16,
#  21,
#  32,
#  41,
#  45,
#  1,
#  12,
#  14,
#  32,
#  42,
#  51,
#  68,
#  1,
#  10,
#  12,
#  14,
#  16,
#  19,
#  26,
#  34,
#  41,
#  45,
#  5,
#  12,
#  16,
#  31,
#  40,
#  42,
#  45,
#  12,
#  16,
#  30,
#  31,
#  35,
#  42,
#  45,
#  51,
#  61,
#  1,
#  2,
#  4,
#  12,
#  21,
#  31,
#  41,
#  45,
#  74,
#  12,
#  14,
#  16,
#  30,
#  36,
#  42,
#  45,
#  52,
#  1,
#  2,
#  4,
#  12,
#  14,
#  16,
#  18,
#  19,
#  30,
#  32,
#  34,
#  39,
#  40,
#  45,
#  18,
#  45,
#  3,
#  7,
#  12,
#  16,
#  31,
#  36,
#  45,
#  1,
#  5,
#  31,
#  39,
#  26,
#  12,
#  14,
#  16,
#  34,
#  36,
#  51,
#  55,
#  2,
#  12,
#  14,
#  16,
#  18,
#  34,
#  42,
#  45,
#  2,
#  12,
#  16,
#  42,
#  45,
#  51,
#  1,
#  2,
#  7,
#  31,
#  33,
#  42,
#  43,
#  45,
#  1,
#  5,
#  12,
#  36,
#  42,
#  51,
#  55,
#  2,
#  4,
#  7,
#  12,
#  14,
#  16,
#  18,
#  34,
#  36,
#  42,
#  45,
#  51,
#  1,
#  4,
#  10,
#  12,
#  14,
#  16,
#  18,
#  21,
#  38,
#  39,
#  42,
#  45,
#  5,
#  10,
#  14,
#  19,
#  26,
#  34,
#  36,
#  40,
#  42,
#  45,
#  1,
#  16,
#  18,
#  51,
#  51,
#  1,
#  4,
#  12,
#  16,
#  19,
#  32,
#  39,
#  42,
#  51,
#  12,
#  14,
#  18,
#  31,
#  34,
#  36,
#  42,
#  45,
#  1,
#  26,
#  42,
#  43,
#  45,
#  1,
#  4,
#  12,
#  16,
#  36,
#  42,
#  45,
#  1,
#  16,
#  18,
#  32,
#  35,
#  42,
#  45,
#  1,
#  18,
#  31,
#  35,
#  36,
#  42,
#  45,
#  1,
#  2,
#  4,
#  10,
#  11,
#  12,
#  14,
#  16,
#  21,
#  26,
#  42,
#  45,
#  55,
#  64,
#  68,
#  1,
#  12,
#  18,
#  31,
#  51,
#  74,
#  16,
#  18,
#  43,
#  16,
#  26,
#  45,
#  16,
#  32,
#  42,
#  45,
#  55,
#  16,
#  26,
#  35,
#  42,
#  45,
#  47,
#  16,
#  18,
#  51,
#  1,
#  2,
#  14,
#  16,
#  18,
#  36,
#  42,
#  45,
#  55,
#  1,
#  14,
#  16,
#  19,
#  21,
#  34,
#  39,
#  42,
#  43,
#  14,
#  16,
#  20,
#  31,
#  34,
#  39,
#  40,
#  42,
#  45,
#  51,
#  16,
#  19,
#  21,
#  26,
#  41,
#  45,
#  55,
#  63,
#  2,
#  5,
#  7,
#  12,
#  16,
#  32,
#  39,
#  41,
#  45,
#  55,
#  1,
#  12,
#  14,
#  16,
#  18,
#  42,
#  45,
#  47,
#  12,
#  16,
#  20,
#  31,
#  35,
#  39,
#  42,
#  45,
#  1,
#  16,
#  19,
#  32,
#  33,
#  40,
#  41,
#  2,
#  16,
#  21,
#  35,
#  39,
#  41,
#  61,
#  1,
#  2,
#  5,
#  7,
#  12,
#  14,
#  15,
#  16,
#  18,
#  30,
#  34,
#  36,
#  39,
#  42,
#  11,
#  1,
#  12,
#  14,
#  16,
#  31,
#  39,
#  42,
#  43,
#  51,
#  2,
#  14,
#  16,
#  18,
#  34,
#  36,
#  72,
#  3,
#  6,
#  14,
#  20,
#  30,
#  31,
#  34,
#  1,
#  12,
#  15,
#  16,
#  18,
#  39,
#  47,
#  54,
#  12,
#  39,
#  40,
#  41,
#  7,
#  16,
#  19,
#  21,
#  26,
#  40,
#  1,
#  2,
#  10,
#  16,
#  17,
#  26,
#  28,
#  39,
#  42,
#  51,
#  53,
#  1,
#  7,
#  14,
#  16,
#  20,
#  39,
#  42,
#  53,
#  69,
#  1,
#  3,
#  12,
#  16,
#  20,
#  26,
#  31,
#  36,
#  39,
#  5,
#  7,
#  11,
#  14,
#  16,
#  36,
#  41,
#  42,
#  45,
#  1,
#  26,
#  32,
#  36,
#  45,
#  1,
#  10,
#  12,
#  26,
#  31,
#  39,
#  41,
#  51,
#  55,
#  1,
#  3,
#  12,
#  14,
#  16,
#  18,
#  20,
#  26,
#  31,
#  34,
#  36,
#  39,
#  41,
#  45,
#  51,
#  18,
#  36,
#  39,
#  42,
#  52,
#  4,
#  10,
#  12,
#  14,
#  24,
#  31,
#  42,
#  45,
#  10,
#  12,
#  16,
#  26,
#  41,
#  43,
#  45,
#  61,
#  9,
#  12,
#  28,
#  36,
#  39,
#  40,
#  51,
#  1,
#  2,
#  14,
#  21,
#  26,
#  45,
#  47,
#  56,
#  1,
#  14,
#  15,
#  34,
#  42,
#  45,
#  16,
#  18,
#  24,
#  51,
#  1,
#  2,
#  5,
#  10,
#  12,
#  14,
#  16,
#  21,
#  26,
#  34,
#  36,
#  39,
#  42,
#  43,
#  45,
#  47,
#  2,
#  5,
#  12,
#  16,
#  21,
#  26,
#  39,
#  42,
#  45,
#  55,
#  57,
#  2,
#  3,
#  12,
#  16,
#  30,
#  31,
#  36,
#  39,
#  40,
#  43,
#  45,
#  51,
#  11,
#  14,
#  36,
#  40,
#  42,
#  45,
#  68,
#  1,
#  14,
#  33,
#  34,
#  36,
#  45,
#  1,
#  4,
#  5,
#  12,
#  14,
#  34,
#  42,
#  51,
#  55,
#  1,
#  5,
#  12,
#  14,
#  16,
#  19,
#  20,
#  34,
#  42,
#  45,
#  55,
#  1,
#  2,
#  11,
#  12,
#  14,
#  16,
#  21,
#  24,
#  31,
#  34,
#  36,
#  37,
#  39,
#  42,
#  1,
#  2,
#  7,
#  11,
#  12,
#  14,
#  16,
#  18,
#  20,
#  26,
#  39,
#  42,
#  45,
#  53,
#  68,
#  39,
#  1,
#  2,
#  10,
#  12,
#  19,
#  36,
#  39,
#  40,
#  41,
#  45,
#  2,
#  5,
#  12,
#  18,
#  19,
#  21,
#  39,
#  72,
#  2,
#  12,
#  16,
#  18,
#  42,
#  51,
#  55,
#  2,
#  7,
#  18,
#  32,
#  36,
#  42,
#  45,
#  2,
#  4,
#  12,
#  14,
#  16,
#  19,
#  20,
#  34,
#  39,
#  41,
#  68,
#  1,
#  2,
#  5,
#  7,
#  12,
#  16,
#  19,
#  30,
#  39,
#  45,
#  55,
#  3,
#  4,
#  10,
#  16,
#  29,
#  31,
#  36,
#  38,
#  40,
#  41,
#  45,
#  68,
#  1,
#  2,
#  9,
#  12,
#  14,
#  16,
#  18,
#  36,
#  39,
#  42,
#  45,
#  51,
#  55,
#  16,
#  2,
#  5,
#  14,
#  29,
#  31,
#  34,
#  42,
#  51,
#  1,
#  2,
#  5,
#  7,
#  10,
#  16,
#  18,
#  20,
#  26,
#  33,
#  36,
#  45,
#  53,
#  55,
#  68,
#  3,
#  5,
#  12,
#  14,
#  34,
#  36,
#  39,
#  40,
#  42,
#  14,
#  16,
#  39,
#  42,
#  69,
#  2,
#  4,
#  5,
#  12,
#  18,
#  19,
#  45,
#  2,
#  12,
#  16,
#  18,
#  36,
#  42,
#  18,
#  36,
#  42,
#  45,
#  1,
#  2,
#  14,
#  16,
#  28,
#  31,
#  38,
#  42,
#  18,
#  19,
#  36,
#  ...]

# %%
keyphrase_count = pd.DataFrame.from_dict({'keyphrase': keyphrase_index_flatten_list, 
                        'count': np.ones(len(keyphrase_index_flatten_list))}).groupby(['keyphrase'])['count'].sum().to_frame().reset_index().sort_values('count', ascending=False)
keyphrase_count = keyphrase_count.reset_index(drop=True).reset_index()

# %%
keyphrase_count['count'] = keyphrase_count['count'] / len(cur_df)
keyphrase_count
# Out:
#     index  keyphrase     count
# 0       0          1  0.518861
# 1       1         16  0.382189
# 2       2         14  0.346644
# 3       3         44  0.284832
# 4       4         43  0.267823
# 5       5          2  0.242308
# 6       6         55  0.240657
# 7       7         42  0.234892
# 8       8         12  0.209686
# 9       9         21  0.209655
# 10     10         39  0.193996
# 11     11         45  0.191016
# 12     12          6  0.181942
# 13     13          0  0.177250
# 14     14         50  0.159302
# 15     15         11  0.139109
# 16     16         58  0.129599
# 17     17          8  0.128382
# 18     18          5  0.120619
# 19     19         36  0.112525
# 20     20         18  0.108168
# 21     21         41  0.105070
# 22     22         10  0.101456
# 23     23         24  0.098842
# 24     24         51  0.094556
# 25     25         47  0.093330
# 26     26         30  0.084419
# 27     27         31  0.083280
# 28     28          4  0.082850
# 29     29         40  0.081573
# ..    ...        ...       ...
# 45     45         71  0.049351
# 46     46         60  0.046636
# 47     47         52  0.043042
# 48     48          7  0.041710
# 49     49         64  0.041489
# 50     50         17  0.041040
# 51     51         32  0.040759
# 52     52         23  0.040381
# 53     53         28  0.033097
# 54     54         27  0.032806
# 55     55         29  0.032497
# 56     56         15  0.032441
# 57     57          3  0.031940
# 58     58         35  0.031567
# 59     59         63  0.030558
# 60     60         66  0.025641
# 61     61         53  0.024757
# 62     62         46  0.023504
# 63     63         72  0.022928
# 64     64         59  0.022266
# 65     65         69  0.022240
# 66     66         48  0.019786
# 67     67         54  0.019748
# 68     68         73  0.019584
# 69     69         33  0.017726
# 70     70         25  0.015151
# 71     71         70  0.013361
# 72     72         37  0.011451
# 73     73         57  0.011126
# 74     74         49  0.009906
#
# [75 rows x 3 columns]

# %%
# fig9 = plt.figure(figsize=(3, 3), dpi=100)
# ax9 = fig9.add_subplot(111)

sns.set_context("paper", rc={"font.size":8,"axes.titlesize":8,"axes.labelsize":8})  

fig, ax = plt.subplots(figsize=(4, 1.5), dpi=100)
ax = sns.barplot(x="index", y='count', data=keyphrase_count, color="white", edgecolor=".2")

# vals = ax.get_yticks()
# ax.set_yticklabels(['{:,.2%}'.format(x) for x in vals])

# ax.set_xlim(0,75)
# ax.set_ylim(0,0.55)

import matplotlib.ticker as ticker
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())

ax.set_xlabel("Beer Key Phrases Index")
ax.set_ylabel("key phrase\ncoverage")
# legend = plt.legend(loc='upper right', shadow=True, fontsize=10)
# legend = plt.legend(shadow=True, fontsize=10)
handles, labels = ax.get_legend_handles_labels()
plt.tight_layout()
fig_path = '../figs'
name = 'beer_keyphrase_coverage'
fig.savefig('{0}/{1}.pdf'.format(fig_path, name), bbox_inches="tight", pad_inches=0, format='pdf')
