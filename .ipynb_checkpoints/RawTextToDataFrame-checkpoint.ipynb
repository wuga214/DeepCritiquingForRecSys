# %%
import time
import gzip
import simplejson
import pandas as pd
from tqdm import tqdm

# %%
def parse(filename):
    f = gzip.open(filename, 'r')
    entry = {}
    for l in f:
        l = l.strip()
        colonPos = l.find(':')
        if colonPos == -1:
            yield entry
            entry = {}
            continue
        eName = l[:colonPos]
        rest = l[colonPos+2:]
        entry[eName] = rest
    yield entry
    
    
data_dict = []

for e in tqdm(parse("data/beer/advocate/Beeradvocate.txt.gz")):
    try:
        e['review/appearance'] = float(e['review/appearance'])
        e['review/taste'] = float(e['review/taste'])
        e['review/overall'] = float(e['review/overall'])
        e['review/palate'] = float(e['review/palate'])
        e['review/aroma'] = float(e['review/aroma'])
        e['review/timeUnix'] = int(e['review/time'])
        e.pop('review/time', None)
        try:
            e['beer/ABV'] = float(e['beer/ABV'])
        except Exception as q:
            e.pop('beer/ABV', None)
        e['user/profileName'] = e['review/profileName']
        e.pop('review/profileName', None)
        timeStruct = time.gmtime(e['review/timeUnix'])
        e['review/timeStruct'] = dict(zip(["year", "mon", "mday", "hour", 
                                           "min", "sec", "wday", "yday", "isdst"], list(timeStruct)))
        data_dict.append(e)
    except Exception as q:
        pass
# Out:
# 1586615it [01:09, 22803.53it/s]

# %%
df = pd.DataFrame(data_dict)

# %%
df.head()
# Out:
#    beer/ABV beer/beerId beer/brewerId               beer/name  \
# 0       5.0       47986         10325            Sausa Weizen
# 1       6.2       48213         10325                Red Moon
# 2       6.5       48215         10325  Black Horse Black Beer
# 3       5.0       47969         10325              Sausa Pils
# 4       7.7       64883          1075           Cauldron DIPA
#
#                        beer/style  review/appearance  review/aroma  \
# 0                      Hefeweizen                2.5           2.0
# 1              English Strong Ale                3.0           2.5
# 2          Foreign / Export Stout                3.0           2.5
# 3                 German Pilsener                3.5           3.0
# 4  American Double / Imperial IPA                4.0           4.5
#
#    review/overall  review/palate  review/taste  \
# 0             1.5            1.5           1.5
# 1             3.0            3.0           3.0
# 2             3.0            3.0           3.0
# 3             3.0            2.5           3.0
# 4             4.0            4.0           4.5
#
#                                          review/text  \
# 0  A lot of foam. But a lot.\tIn the smell some b...
# 1  Dark red color, light beige foam, average.\tIn...
# 2  Almost totally black. Beige foam, quite compac...
# 3  Golden yellow color. White, compact foam, quit...
# 4  According to the website, the style for the Ca...
#
#                                    review/timeStruct  review/timeUnix  \
# 0  {u'isdst': 0, u'mday': 16, u'hour': 20, u'min'...       1234817823
# 1  {u'isdst': 0, u'mday': 1, u'hour': 13, u'min':...       1235915097
# 2  {u'isdst': 0, u'mday': 1, u'hour': 14, u'min':...       1235916604
# 3  {u'isdst': 0, u'mday': 15, u'hour': 19, u'min'...       1234725145
# 4  {u'isdst': 0, u'mday': 30, u'hour': 18, u'min'...       1293735206
#
#   user/profileName
# 0          stcules
# 1          stcules
# 2          stcules
# 3          stcules
# 4   johnmichaelsen

# %%
columnToDrop = ['review/appearance','review/aroma','review/palate',
                'review/taste','review/timeStruct', 'beer/beerId', 'beer/brewerId']
df = df.drop(columnToDrop, axis=1)

# %%
df.dtypes
# Out:
# beer/ABV            float64
# beer/name            object
# beer/style           object
# review/overall      float64
# review/text          object
# review/timeUnix       int64
# user/profileName     object
# dtype: object

# %%
df.head()
# Out:
#    beer/ABV               beer/name                      beer/style  \
# 0       5.0            Sausa Weizen                      Hefeweizen
# 1       6.2                Red Moon              English Strong Ale
# 2       6.5  Black Horse Black Beer          Foreign / Export Stout
# 3       5.0              Sausa Pils                 German Pilsener
# 4       7.7           Cauldron DIPA  American Double / Imperial IPA
#
#    review/overall                                        review/text  \
# 0             1.5  A lot of foam. But a lot.\tIn the smell some b...
# 1             3.0  Dark red color, light beige foam, average.\tIn...
# 2             3.0  Almost totally black. Beige foam, quite compac...
# 3             3.0  Golden yellow color. White, compact foam, quit...
# 4             4.0  According to the website, the style for the Ca...
#
#    review/timeUnix user/profileName
# 0       1234817823          stcules
# 1       1235915097          stcules
# 2       1235916604          stcules
# 3       1234725145          stcules
# 4       1293735206   johnmichaelsen

# %%
df.to_csv('data/beer/advocate/RefinedRawData.csv')
