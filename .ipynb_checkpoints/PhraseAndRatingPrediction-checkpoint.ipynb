# %%
import re
import ast
import itertools
from collections import Counter
import pandas as pd
import numpy as np
import scipy.sparse as sparse

from keras.preprocessing.text import one_hot
from keras.preprocessing.text import text_to_word_sequence
from keras.preprocessing.text import Tokenizer
from keras.utils import plot_model

from IPython.display import Image
import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %%
itemIndex = 'ItemIndex'
userIndex = 'UserIndex'
rating = 'review/overall'
binary = 'Binary'
keyPhrase = 'keyVector'
dataPath = 'data/beer/advocate/'
dataName = 'Data.csv'
KeyPhraseName = 'KeyPhrases.csv'
embedding_dims = 100
num_keyPhrases = 100

# %%
df = pd.read_csv(dataPath+dataName)
df.head()
# Out:
#    Unnamed: 0  beer/ABV                      beer/style  review/overall  \
# 0           0       5.0                      Hefeweizen             1.5
# 1           1       6.2              English Strong Ale             3.0
# 2           2       6.5          Foreign / Export Stout             3.0
# 3           3       5.0                 German Pilsener             3.0
# 4           4       7.7  American Double / Imperial IPA             4.0
#
#    review/timeUnix         keyVector  UserIndex  ItemIndex  Binary
# 0       1234817823                []    10907.0       2809       0
# 1       1235915097                []    10907.0       2650       0
# 2       1235916604                []    10907.0        463       0
# 3       1234725145                []    10907.0       2808       0
# 4       1293735206  [12, 28, 50, 51]     8278.0        709       0

# %%
num_user = df[userIndex].nunique()
num_item = df[itemIndex].nunique()
print("Number of User: {0}".format(num_user))
print("Number of Item: {0}".format(num_item))
print("Number of key Phrase: {0}".format(num_keyPhrases))
# Out:
# Number of User: 11950
# Number of Item: 3688
# Number of key Phrase: 100

# %%
def getSparseMatrixFromLists(keyvector):
    indecs = []
    for i in range(len(keyvector)):
        for j in keyvector[i]:
            indecs.append([i,j])
            
    indecs = np.array(indecs)
    return sparse.csr_matrix((np.ones(len(indecs)), (indecs[:,0], indecs[:,1])), shape=(len(keyvector), num_keyPhrases))

# %%
msk = np.random.rand(len(df)) < 0.8
train_df = df[msk]
test_df = df[~msk]

# %%
def getArrays(df):
    users = df[userIndex].as_matrix()
    items = df[itemIndex].as_matrix()
    ratings = df[binary].as_matrix()
    keys = getSparseMatrixFromLists(df[keyPhrase].apply(ast.literal_eval).values.tolist())
    return [users,items,ratings,keys]

train_array = getArrays(train_df)
test_array = getArrays(test_df)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Negative Sampling
# Use negative sampling only when implicit feedback!

# %%
# def negative_data(df, size_per_user):

#     m = df[userIndex].nunique()
#     n = df[itemIndex].nunique()
    
#     users = []
#     items = []

#     negative_data = []
#     for i in range(m):
#         sampled_items = np.random.choice(n, size_per_user, replace=False)
#         observed_items = df[df[userIndex] == i][itemIndex].as_matrix().flatten()
#         sampled_items = sampled_items[np.invert(np.isin(sampled_items, observed_items))]
#         users += [i]*len(sampled_items)
#         items += sampled_items.tolist()
        
#     ratings = [0]*len(users)
#     keys = np.zeros([len(users), num_keyPhrases])

#     return [np.array(users),np.array(items),np.array(ratings),keys]
# negative_data = negative_data(train_df, 100)

# %%
# def concateData(positive, negative):
#     users = np.concatenate([positive[0], negative[0]])
#     items = np.concatenate([positive[1], negative[1]])
#     ratings = np.concatenate([positive[2], negative[2]])
#     keys = np.concatenate([positive[3], negative[3]])
#     return [np.array(users),np.array(items),np.array(ratings),keys]

# train_array = concateData(train_array, negative_data)

# %% [markdown]
# ## Model

# %%
from keras.models import Model
from keras.layers import *   
from keras.backend import reshape

# %%
def build_model():
    userIndex = Input(shape=(1,), name='userIndex')
    itemIndex = Input(shape=(1,), name='itemIndex')

    userEmbedding = Embedding(num_user, embedding_dims, name='userEmbedding')(userIndex)
    itemEmbedding = Embedding(num_item, embedding_dims, name='itemEmbedding')(itemIndex)

    merged = concatenate([userEmbedding, itemEmbedding])
    x = Flatten()(merged)
    #x = BatchNormalization()(x)
    x = Activation('selu')(x)
    x = Dropout(0.1)(x)
    # a layer instance is callable on a tensor, and returns a tensor
    x = Dense(128)(x)
    #x = BatchNormalization()(x)
    x = Activation('selu')(x)
    hidden = Dropout(0.1)(x)
    pred_rating= Dense(1, name='rating')(hidden)
    pred_keyPhrase= Dense(num_keyPhrases, name='keyPhrase')(hidden)

    # This creates a model that includes
    # the Input layer and three Dense layers
    model = Model(inputs=[userIndex, itemIndex], outputs=[pred_rating, pred_keyPhrase])
    model.compile(optimizer='rmsprop',
                  loss=["mean_squared_error", "mean_squared_error"],
                  loss_weights = [1.1,1])

    return model

model = build_model()

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# userIndex (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# itemIndex (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# userEmbedding (Embedding)       (None, 1, 100)       1195000     userIndex[0][0]
# __________________________________________________________________________________________________
# itemEmbedding (Embedding)       (None, 1, 100)       368800      itemIndex[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1, 200)       0           userEmbedding[0][0]
#                                                                  itemEmbedding[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 200)          0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 200)          0           flatten_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 200)          0           activation_13[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          25728       dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128)          0           activation_14[0][0]
# __________________________________________________________________________________________________
# rating (Dense)                  (None, 1)            129         dropout_10[0][0]
# __________________________________________________________________________________________________
# keyPhrase (Dense)               (None, 100)          12900       dropout_10[0][0]
# ==================================================================================================
# Total params: 1,602,557
# Trainable params: 1,602,557
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# plot_model(model, to_file='multiple_outputs.png')
# Image(filename='multiple_outputs.png')

# %%
history = model.fit(train_array[:2], train_array[2:], 
                    validation_data=(test_array[:2], test_array[2:]), epochs=10, batch_size=32)
# Out:
# Train on 69979 samples, validate on 30021 samples
# Epoch 1/10
# 69979/69979 [==============================] - 16s 230us/step - loss: 0.2262 - rating_loss: 0.1932 - keyPhrase_loss: 0.0137 - val_loss: 0.2262 - val_rating_loss: 0.1935 - val_keyPhrase_loss: 0.0133
# Epoch 2/10
# 69979/69979 [==============================] - 15s 221us/step - loss: 0.2153 - rating_loss: 0.1836 - keyPhrase_loss: 0.0134 - val_loss: 0.2207 - val_rating_loss: 0.1886 - val_keyPhrase_loss: 0.0133
# Epoch 3/10
# 69979/69979 [==============================] - 15s 221us/step - loss: 0.2118 - rating_loss: 0.1804 - keyPhrase_loss: 0.0133 - val_loss: 0.2237 - val_rating_loss: 0.1914 - val_keyPhrase_loss: 0.0132
# Epoch 4/10
# 69979/69979 [==============================] - 15s 220us/step - loss: 0.2102 - rating_loss: 0.1790 - keyPhrase_loss: 0.0133 - val_loss: 0.2211 - val_rating_loss: 0.1890 - val_keyPhrase_loss: 0.0132
# Epoch 5/10
# 69979/69979 [==============================] - 16s 222us/step - loss: 0.2095 - rating_loss: 0.1784 - keyPhrase_loss: 0.0132 - val_loss: 0.2213 - val_rating_loss: 0.1892 - val_keyPhrase_loss: 0.0132
# Epoch 6/10
# 69979/69979 [==============================] - 16s 222us/step - loss: 0.2089 - rating_loss: 0.1778 - keyPhrase_loss: 0.0132 - val_loss: 0.2214 - val_rating_loss: 0.1894 - val_keyPhrase_loss: 0.0131
# Epoch 7/10
# 69979/69979 [==============================] - 15s 221us/step - loss: 0.2086 - rating_loss: 0.1776 - keyPhrase_loss: 0.0132 - val_loss: 0.2262 - val_rating_loss: 0.1937 - val_keyPhrase_loss: 0.0131
# Epoch 8/10
# 69979/69979 [==============================] - 15s 217us/step - loss: 0.2083 - rating_loss: 0.1774 - keyPhrase_loss: 0.0132 - val_loss: 0.2203 - val_rating_loss: 0.1884 - val_keyPhrase_loss: 0.0131
# Epoch 9/10
# 69979/69979 [==============================] - 15s 219us/step - loss: 0.2074 - rating_loss: 0.1766 - keyPhrase_loss: 0.0132 - val_loss: 0.2225 - val_rating_loss: 0.1903 - val_keyPhrase_loss: 0.0132
# Epoch 10/10
# 69979/69979 [==============================] - 15s 221us/step - loss: 0.2028 - rating_loss: 0.1723 - keyPhrase_loss: 0.0133 - val_loss: 0.2404 - val_rating_loss: 0.2062 - val_keyPhrase_loss: 0.0136

# %%
# # Plot training & validation accuracy values
# plt.plot(history.history['rating_acc'])
# plt.plot(history.history['val_rating_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
# Plot training & validation loss values
plt.plot(history.history['rating_loss'])
plt.plot(history.history['val_rating_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# # Plot training & validation accuracy values
# plt.plot(history.history['keyPhrase_acc'])
# plt.plot(history.history['val_keyPhrase_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()
# Plot training & validation loss values
plt.plot(history.history['keyPhrase_loss'])
plt.plot(history.history['val_keyPhrase_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
prediction = model.predict(test_array[:2])

# %%
prediction
# Out:
# [array([[-4.1311979e-04],
#         [ 9.3576312e-04],
#         [ 2.1871975e-01],
#         ...,
#         [ 1.3985693e-02],
#         [ 7.4364865e-01],
#         [ 2.7188641e-01]], dtype=float32),
#  array([[ 0.07051617,  0.08143623,  0.0554124 , ...,  0.04430899,
#          -0.05412488,  0.03343216],
#         [ 0.06068221,  0.06647418,  0.05308445, ...,  0.0442742 ,
#          -0.05410244,  0.03371049],
#         [ 0.06423302,  0.086077  ,  0.053532  , ...,  0.00887465,
#          -0.0080411 ,  0.00916987],
#         ...,
#         [ 0.0361461 ,  0.09603088,  0.02608025, ...,  0.04134245,
#          -0.05120714,  0.03295315],
#         [ 0.02476769,  0.02835642,  0.02530555, ..., -0.01317489,
#           0.01516453, -0.00985654],
#         [ 0.07119113,  0.04523465,  0.07151644, ...,  0.01091125,
#          -0.01340265,  0.00874832]], dtype=float32)]

# %%
def PredictTopK(model, topK_item, topK_keyPhrase, keyPhrase):
    
    explain_dicts = []
    for i in tqdm(range(5)):
        inputs = [np.array([i]*num_item), np.arange(num_item)]
        predictions = model.predict(inputs)
        index_topK = np.argsort(predictions[0].flatten())[::-1][:topK_item]
        for j in index_topK:
            explain = keyPhrase[np.argsort(predictions[1][j].flatten())[::-1][:topK_keyPhrase]]
            explain_dicts.append({'UserIndex': i, 'ItemIndex': j, 'Explanation': explain})
            
    return pd.DataFrame(explain_dicts)

# %%
df = pd.read_csv(dataPath+KeyPhraseName)
keyPhrase = np.array(df['Phrases'].tolist())

# %%
df_explain = PredictTopK(model, 10, 3, keyPhrase)
# Out:
# 100%|██████████| 5/5 [00:00<00:00,  7.67it/s]

# %%
df_explain
# Out:
#                                        Explanation  ItemIndex  UserIndex
# 0             [dark chocol, veri easi, mapl syrup]       1173          0
# 1             [dark chocol, brown head, veri easi]       1226          0
# 2          [brown sugar, finger head, dark chocol]        861          0
# 3           [dark chocol, brown sugar, brown head]       2419          0
# 4           [copper color, veri easi, finger head]       1706          0
# 5            [dark chocol, brown head, dark roast]       1172          0
# 6            [dark chocol, dark fruit, brown head]        484          0
# 7          [dark chocol, brown sugar, finger head]        759          0
# 8           [finger head, copper color, veri easi]       2908          0
# 9         [copper color, finger head, brown sugar]        292          0
# 10     [dark chocol, finger white head, veri easi]       1173          1
# 11             [dark chocol, oz bottl, brown head]       1226          1
# 12    [dark chocol, great beer, finger white head]        861          1
# 13           [dark chocol, brown head, great beer]       2419          1
# 14     [oz bottl, copper color, finger white head]       1706          1
# 15             [dark chocol, brown head, oz bottl]       1172          1
# 16           [dark chocol, dark fruit, brown head]        484          1
# 17     [oz bottl, finger white head, copper color]       2908          1
# 18             [dark chocol, brown head, oz bottl]        759          1
# 19           [oz bottl, amber color, copper color]        292          1
# 20    [dark chocol, finger white head, brown head]       1173          2
# 21             [dark chocol, brown head, oz bottl]       1226          2
# 22    [dark chocol, great beer, finger white head]        861          2
# 23           [dark chocol, brown head, great beer]       2419          2
# 24  [finger white head, session beer, amber color]       1706          2
# 25             [dark chocol, brown head, oz bottl]       1172          2
# 26           [dark chocol, dark fruit, brown head]        484          2
# 27            [dark chocol, brown head, beer pour]        759          2
# 28      [oz bottl, finger white head, finger head]       2908          2
# 29         [amber color, citrus hop, session beer]        292          2
# 30    [dark chocol, finger white head, great beer]       1173          3
# 31             [dark chocol, oz bottl, brown head]       1226          3
# 32    [dark chocol, great beer, finger white head]        861          3
# 33           [dark chocol, brown head, great beer]       2419          3
# 34       [finger white head, great beer, oz bottl]       1706          3
# 35             [dark chocol, brown head, oz bottl]       1172          3
# 36           [dark chocol, dark fruit, brown head]        484          3
# 37      [oz bottl, finger white head, finger head]       2908          3
# 38           [dark chocol, brown head, great beer]        759          3
# 39             [oz bottl, finger head, great beer]        292          3
# 40    [dark chocol, finger white head, great beer]       1173          4
# 41             [dark chocol, oz bottl, brown head]       1226          4
# 42    [dark chocol, great beer, finger white head]        861          4
# 43           [dark chocol, great beer, brown head]       2419          4
# 44            [oz bottl, great beer, session beer]       1706          4
# 45             [dark chocol, brown head, oz bottl]       1172          4
# 46           [dark chocol, dark fruit, brown head]        484          4
# 47             [dark chocol, great beer, oz bottl]        759          4
# 48       [oz bottl, finger white head, great beer]       2908          4
# 49             [oz bottl, amber color, great beer]        292          4

# %% [markdown]
# # Problem
# it seems key word selected from data processing has problem. Those keys phrases are too sparse and also not very informative. Should think better idea to extract key phrases.
