# %%
import pandas as pd
import numpy as np
import gzip

import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from keras.preprocessing.text import Tokenizer
# Out:
# /home/kai/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
ITEM_ID = 'asin'
USER_ID = 'reviewerID'
RATING = 'overall'
REVIEW_TEXT = 'reviewText'
TIMESTAMP = 'unixReviewTime'
KEYPHRASE = 'keyVector'
BINARY_RATING = 'Binary'
NUM_KEYPHRASE = 100
DATA_PATH = '../NCE_Projected_LRec/data/amazon/raw/'
DATA_NAME = 'reviews_CDs_and_Vinyl_5'
DATA_EXTENSION = '.json.gz'

# %% [markdown]
# # Load Dataset

# %%
def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

# %%
df = getDF(DATA_PATH+DATA_NAME+DATA_EXTENSION)[[USER_ID, ITEM_ID, RATING, TIMESTAMP, REVIEW_TEXT]]
df[REVIEW_TEXT] = df[REVIEW_TEXT].astype('str')
df[USER_ID] = df[USER_ID].astype('str')
df[ITEM_ID] = df[ITEM_ID].astype('str')

# %%
def filter_dataset(df, threshold=3, popularity=True, filter_by_review_count=True, 
                   user_review_threshold=10, item_review_threshold=10, 
                   num_user=None, num_item=None, user_ratio=0.25, item_ratio=0.2):
    # Binarize rating
    df[BINARY_RATING] = (df[RATING] > threshold)*1

    # Filter dataset only based on positive ratings
    df = df[df[BINARY_RATING] == 1]
    
    print("The total number of users is {}".format(df[USER_ID].nunique()))
    print("The total number of items is {} \n".format(df[ITEM_ID].nunique()))
    

    values = df[ITEM_ID].value_counts().keys().tolist()
    counts = df[ITEM_ID].value_counts().tolist()
    item_df = pd.DataFrame.from_dict({ITEM_ID: values, "count": counts})
    
    values = df[USER_ID].value_counts().keys().tolist()
    counts = df[USER_ID].value_counts().tolist()
    user_df = pd.DataFrame.from_dict({USER_ID: values, "count": counts})
    
    if popularity:
        print("Filter dataset by popularity. \n")
        
        if filter_by_review_count:
            print("Filter dataset by review count. \n")
            
            filtered_item_df = item_df[item_df["count"] >= item_review_threshold]
            filtered_item_id = filtered_item_df[ITEM_ID].values
            
            filtered_user_df = user_df[user_df["count"] >= user_review_threshold]
            filtered_user_id = filtered_user_df[USER_ID].values
            
        else:
            print("Filter dataset by user and item number. \n")
            filtered_item_id = item_df[ITEM_ID].unique()[:num_item]
            filtered_user_id = user_df[USER_ID].unique()[:num_user]
            
    else:
        print("Filter dataset by sampling. \n")
        np.random.seed(8292)
        
        filtered_item_id = np.take(item_df[ITEM_ID].unique(), 
                                   indices=np.random.choice(len(item_df), int(item_ratio*len(item_df))))
        filtered_user_id = np.take(user_df[USER_ID].unique(), 
                                   indices=np.random.choice(len(user_df), int(user_ratio*len(user_df))))
        
    df = df.loc[(df[USER_ID].isin(filtered_user_id)) & (df[ITEM_ID].isin(filtered_item_id))]
    
    print("Number of User: {}".format(df[USER_ID].nunique()))
    print("Number of Item: {}".format(df[ITEM_ID].nunique()))

    return df

# %% [markdown]
# # Option1: Filter by popularity, then the number of users and items

# %%
filtered_df = filter_dataset(df, threshold=3, popularity=True, filter_by_review_count=False, 
                             user_review_threshold=None, item_review_threshold=None, 
                             num_user=40000, num_item=4400, user_ratio=None, item_ratio=None)
# Out:
# The total number of users is 75037
# The total number of items is 64356
#
# Filter dataset by popularity.
#
# Filter dataset by user and item number.
#
# Number of User: 35745
# Number of Item: 4400

# %% [markdown]
# # Option2: Filter by popularity, then the number of positive ratings of users and items

# %%
# filtered_df = filter_dataset(df, threshold=3, popularity=True, filter_by_review_count=True, 
#                              user_review_threshold=23, item_review_threshold=40, 
#                              num_user=None, num_item=None, user_ratio=None, item_ratio=None)

# %% [markdown]
# # Option3: Sample from the dataset

# %%
# filtered_df = filter_dataset(df, threshold=3, popularity=False, filter_by_review_count=False, 
#                              user_review_threshold=None, item_review_threshold=None, 
#                              num_user=None, num_item=None, user_ratio=0.25, item_ratio=0.7)

# %% [markdown]
# # Analyze the filtered dataset

# %%
filtered_df.head()
# Out:
#          reviewerID        asin  overall  unixReviewTime  \
# 228  A2K3LZPH3ND94V  0780018664      4.0      1167868800
# 230  A1GSR7RGCG1QYZ  0780018664      5.0      1249344000
# 232  A2GANR9I6XHTU9  0780018664      4.0      1169337600
# 233   ANCOMAI0I7LVG  0780018664      5.0      1213574400
# 234  A1GGOC9PVDXW7Z  0780018664      5.0      1268524800
#
#                                             reviewText  Binary
# 228  This was basically a superior movie, still dar...       1
# 230  From the elongated opening scene of "M", you k...       1
# 232  Filmed in 1931 this is the first serial killer...       1
# 233  My feelings for this iconic piece of filmmakin...       1
# 234  The title M comes from a chalk mark (for 'murd...       1

# %%
values = filtered_df[USER_ID].value_counts().keys().tolist()
counts = filtered_df[USER_ID].value_counts().tolist()
user_df = pd.DataFrame.from_dict({USER_ID: values, "count": counts})

values = filtered_df[ITEM_ID].value_counts().keys().tolist()
counts = filtered_df[ITEM_ID].value_counts().tolist()
item_df = pd.DataFrame.from_dict({ITEM_ID: values, "count": counts})

# %%
item_df.tail()
# Out:
#             asin  count
# 4395  B007PKSN6Q     20
# 4396  B002K0WBM8     19
# 4397  B001RJ1XV8     16
# 4398  B000002O42     11
# 4399  B000006P8O      5

# %%
item_df["count"].mean()
# Out:
# 60.93545454545455

# %%
user_df[user_df["count"] >= 10]
# Out:
#       count      reviewerID
# 0       590  A3KJ6JAZPH382D
# 1       498  A1GN8UJIZLCA59
# 2       472  A1J5KCZC8CMW9I
# 3       430  A2582KMXLK2P06
# 4       429  A3HU0B9XUEVHIM
# 5       405  A26NLSTT75FMJM
# 6       399  A34Y1FT0MTD7C9
# 7       395   ASVNSWIXBV72Q
# 8       373  A12R54MKO17TW0
# 9       342  A1QEWOSV05RYEO
# 10      331  A35GNQK1DC7WXU
# 11      313   AWSYTZ2I2MW0V
# 12      307  A1IKOYZVFHO1XP
# 13      298  A3SV72ZAHH2IDH
# 14      297  A2R6RA8FRBS608
# 15      295  A24N1BAS3CU27H
# 16      294   AKGF27HN0OF19
# 17      288  A2TAPL67U2A5HM
# 18      288  A2TSHD7SWDGS58
# 19      286  A14GK0E64J0WAS
# 20      281  A3AL8GQ69QE7WN
# 21      279   A9Q28YTLYREO7
# 22      277   AE31M52VLKOG6
# 23      273  A1OML05BTJBEKS
# 24      273   AZSN1TO0JI87B
# 25      266   AXFI7TAWD6H6X
# 26      263  A38U2M9OAEJAXJ
# 27      258  A1BJJVV2B5VLUQ
# 28      256  A3T9IX8EDFDX4G
# 29      255   AFEN54UGJQOK9
# ...     ...             ...
# 6026     10  A2O1HTMTUKSMEX
# 6027     10  A274RBONJ55DOH
# 6028     10  A3DMA631JWG6S7
# 6029     10   A8YDK6N6OHMDA
# 6030     10  A12FLBGHU3SSJ9
# 6031     10  A12QL3YE58F9RI
# 6032     10  A27KTK7T4WUZ6V
# 6033     10  A30IUH4AC21ISL
# 6034     10  A2QUBPECRDS7HJ
# 6035     10  A2YTXH623VE9CU
# 6036     10   A7MZFVG8TRSJN
# 6037     10  A2IIAQ7VVAHXTD
# 6038     10  A17J91PKRJR8TU
# 6039     10   AL028ADTAJ41G
# 6040     10  A1L9XSUQBCWZXN
# 6041     10  A1RZFQNM6C3Y0I
# 6042     10  A1CYAHMXNB91EI
# 6043     10  A31CWVNVR0IL9A
# 6044     10  A35YWA2V4QHOJ3
# 6045     10  A37IXNK8TA0IK5
# 6046     10  A2N5HGID7BSNU1
# 6047     10  A3DQYY2XM24E53
# 6048     10   A3XNTYRDE0MFI
# 6049     10  A17KTZ0K8R0X9I
# 6050     10  A1EJGW6OJXC1O2
# 6051     10  A2F7HLFS00FA1J
# 6052     10  A1WFJ04YJEJVA7
# 6053     10  A25FFVHS1CF9UT
# 6054     10  A3MSH2YW203752
# 6055     10  A1ART5LIGLOVZO
#
# [6056 rows x 2 columns]

# %%
users = user_df[user_df["count"] >= 10][USER_ID].values

# %%
pos_df = filtered_df.loc[filtered_df[USER_ID].isin(users)].reset_index(drop=True)
pos_df

# Export the filtered dataset

# pos_df.to_csv(DATA_PATH+DATA_NAME+".csv", header=False)
# Out:
#             reviewerID        asin  overall  unixReviewTime  \
# 0       A2GANR9I6XHTU9  0780018664      4.0      1169337600
# 1        ANCOMAI0I7LVG  0780018664      5.0      1213574400
# 2       A1GGOC9PVDXW7Z  0780018664      5.0      1268524800
# 3        A62G4QX6XQVLP  0780018664      5.0      1165190400
# 4       A2ILOYARQVO4K1  0780018664      4.0       989193600
# 5       A2XKQHB8VCUCJK  0780018664      5.0      1385942400
# 6         AIMR915K4YCN  0780018664      5.0      1083196800
# 7       A1GHUN5HXMHZ89  0780018664      5.0      1300406400
# 8       A2C7BOQVFH1HLE  0780018664      4.0      1302825600
# 9       A25FDX17O3QKLT  0780018664      5.0      1115769600
# 10      A29ND8RD38SEUZ  0780018664      5.0      1358899200
# 11      A16CZRQL23NOIW  0780018664      5.0      1135123200
# 12      A2BLITJITO97N5  0780018664      5.0      1102636800
# 13      A366S12KCZ280V  0780018664      5.0      1376524800
# 14       AS0IKFFQS2HD2  0780018664      5.0      1217894400
# 15      A1UI2N2LBGVKC7  0780018664      5.0       944697600
# 293      M (Fritz Lang, 1931)It has been said that behi...       1
# 298      Some film historics consider it the best film ...       1
# 303      This film breathes with the gritty textures an...       1
# 306      spoilers.This is a great story of an entire ci...       1
# 309      Loved this movie as a kid and still do now. A ...       1
# ...                                                    ...     ...
# 1096600  Jack White never disappoints. I find this to b...       1
# 1096609  I felt that Jack White's first solo album (Blu...       1
# 1096613  "Lazaretto" is excellent! This is an excellent...       1
# 1096614  The order should be:Lazaretto, would you fight...       1
# 1096615  I confess to liking Jack White's music quite a...       1
# 1096618  Three Women - A great starter track and ,upon ...       1
# 1096619  to me Jack White gets it as a musician in that...       1
# 1096622  I fell in love with Jack White's work on "Elep...       1
# 1096625  Excellent follow-up to his debut &#34;Blunderb...       1
# 1096628  Jack Whites requiem is the thing right now in ...       1
# 1097124  And Faulkner is fantastic. He's a fantastic fa...       1
# 1097127  Well, I have to eat crow! I was one of the man...       1
# 1097134  Think about this: how many bands have embarked...       1
# 1097137  I was shocked to hear Priest was coming out wi...       1
# 1097138  This is what real music is all about.  Some pe...       1
# 1097141  I bought this the day it came out and have bee...       1
# 1097146  THE MIGHTY JUDAS PRIEST HAVE RELEASED A GREAT ...       1
# 1097151  When I first got this CD I was a bit skeptical...       1
# 1097155  With a band lke Judas Priest, you're going to ...       1
# 1097156  *This is a review for the deluxe version of th...       1
# 1097162  Whoa, awesome. Beat my expectations. Dare I sa...       1
# 1097164  Judas Priest is simply one of the greatest met...       1
# 1097167  Excellent album. Judas Priest never ever disap...       1
# 1097173  this is an awesome new album by judas preist i...       1
# 1097176  First off, I am a huge Priest fan. This album ...       1
# 1097179  Back to their strengths as one of the great me...       1
# 1097184  Judas Priest last appeared in the form of a me...       1
# 1097187  Redeemer of Souls is a feast of Judas Priest h...       1
# 1097188  ...and maybe since SCREAMING FOR VENGEANCE.My ...       1
# 1097189  This guy are the true king of metal. there not...       1
#
# [152670 rows x 6 columns]

# %% [markdown]
# # Process review

# %%
def process_reviewText(df):

    # Process ReviewText
    df["review"] = df[REVIEW_TEXT].apply(lambda x: nltk.word_tokenize(x)+[' '])

    # Lowercase
    df["review"] = df["review"].apply(lambda text: [w.lower() for w in text])

    # Remove Punctuation
    table = str.maketrans('', '', string.punctuation)
    df["review"] = df["review"].apply(lambda text: [w.translate(table) for w in text])

    # Remove tokens that are not alphabetic
    df["review"] = df["review"].apply(lambda text: [w for w in text if w.isalpha()])

    # Remove Stopwords
    # Get english stopwords
    en_stopwords = set(stopwords.words('english'))
    df["review"] = df["review"].apply(lambda text: [w for w in text if w not in en_stopwords])
    
    return df

# %%
cur_df = process_reviewText(cur_df)
# Out:
# /home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# 1097127  [well, eat, crow, one, many, skeptical, jp, ca...
# 1097132  [admire, band, endurance, longevity, important...
# 1097134  [think, many, bands, embarked, farewell, tours...
# 1097137  [shocked, hear, priest, coming, new, album, ch...
# 1097138  [real, music, people, complaining, mix, parts,...
# 1097141  [bought, day, came, listening, non, stop, good...
# 1097146  [mighty, judas, priest, released, great, metal...
# 1097151  [first, got, cd, bit, skeptical, wondering, ju...
# 1097155  [band, lke, judas, priest, going, find, pletho...
# 1097156  [review, deluxe, version, albumfor, heavy, met...
# 1097159  [heavy, album, references, occult, lyrics, kk,...
# 1097162  [whoa, awesome, beat, expectations, dare, say,...
# 1097164  [judas, priest, simply, one, greatest, metal, ...
# 1097165  [suppose, put, obligatory, credentials, priest...
# 1097167  [excellent, album, judas, priest, never, ever,...
# 1097173  [awesome, new, album, judas, preist, plain, aw...
# 1097176  [first, huge, priest, fan, album, best, worst,...
# 1097177  [music, hard, classic, sorry, write, opinion, ...
# 1097179  [back, strengths, one, great, metal, bands, ev...
# 1097184  [judas, priest, last, appeared, form, metal, f...
# 1097186  [like, new, cd, nt, love, bought, mega, editio...
# 1097187  [redeemer, souls, feast, judas, priest, heavy,...
# 1097188  [maybe, since, screaming, vengeancemy, least, ...
# 1097189  [guy, true, king, metal, nothing, wrong, album...
#
# [182503 rows x 7 columns]

# %% [markdown]
# # Index Words since no further changes will be made on the words

# %%
tokenizer = Tokenizer()
text = cur_df["review"].tolist()
tokenizer.fit_on_texts(text)

# %%
df_word_index = pd.DataFrame(list(tokenizer.word_index.items()), columns=['word','index'])

# %%
df_word_index
# Out:
#                        word   index
# 0                     album       1
# 1                      quot       2
# 2                      song       3
# 3                        nt       4
# 4                       one       5
# 5                      like       6
# 6                     songs       7
# 7                     great       8
# 8                     music       9
# 9                      good      10
# 10                       cd      11
# 11                     best      12
# 12                     band      13
# 13                     love      14
# 14                   really      15
# 15                    first      16
# 16                     time      17
# 17                     rock      18
# 18                    track      19
# 19                    would      20
# 20                    sound      21
# 21                      get      22
# 22                    still      23
# 23                   albums      24
# 24                     well      25
# 25                     even      26
# 26                     much      27
# 27                     also      28
# 28                   tracks      29
# 29                      new      30
# ...                     ...     ...
# 400870           blueshonky  400871
# 400871             rocksits  400872
# 400872             highball  400873
# 400873           rhythmsolo  400874
# 400874          trackpriest  400875
# 400875              tippton  400876
# 400876            hillwhile  400877
# 400877          eraredeemer  400878
# 400878         createhighly  400879
# 400879                tympo  400880
# 400880             redemmer  400881
# 400881  bangcongratulations  400882
# 400882        evenpackaging  400883
# 400883      graphicsartwork  400884
# 400884             theirsto  400885
# 400885    magneticmetallica  400886
# 400886          quessnryche  400887
# 400887          inexcuseble  400888
# 400888           intendedok  400889
# 400889             democles  400890
# 400890      productioncheck  400891
# 400891          statesmanas  400892
# 400892                 bote  400893
# 400893          leftoversmy  400894
# 400894        dragonautlong  400895
# 400895          vengeancemy  400896
# 400896         chorusmoving  400897
# 400897            neardoomy  400898
# 400898     painkillerbottom  400899
# 400899            saidgrade  400900
#
# [400900 rows x 2 columns]

# %% [markdown]
# # Get Token List

# %%
token_list = cur_df["review"].tolist()

# %%
token_list[0]
# Out:
# ['filmed',
#  'first',
#  'serial',
#  'killer',
#  'movie',
#  'story',
#  'serial',
#  'killer',
#  'terrorizes',
#  'german',
#  'town',
#  'follow',
#  'story',
#  'get',
#  'see',
#  'city',
#  'going',
#  'mad',
#  'hunt',
#  'killer',
#  'killer',
#  'work',
#  'eventually',
#  'lorre',
#  'fleeing',
#  'life',
#  'killer',
#  'strikes',
#  'hes',
#  'always',
#  'whistling',
#  'haunting',
#  'tune',
#  'eerie',
#  'blind',
#  'man',
#  'sells',
#  'balloons',
#  'ends',
#  'using',
#  'keen',
#  'observances',
#  'hearing',
#  'whistling',
#  'putting',
#  'together',
#  'eventually',
#  'aiding',
#  'capture',
#  'bringing',
#  'killer',
#  'justicethe',
#  'imagery',
#  'haunting',
#  'whistling',
#  'creepy',
#  'really',
#  'grates',
#  'nerves',
#  'scariness',
#  'dont',
#  'see',
#  'kind',
#  'deal',
#  'ive',
#  'also',
#  'heard',
#  'film',
#  'somewhat',
#  'models',
#  'story',
#  'german',
#  'serial',
#  'killer',
#  'peter',
#  'kurten',
#  'aka',
#  'vampire',
#  'dusseldorf',
#  'commiting',
#  'assaults',
#  'murders',
#  'children',
#  'fritz',
#  'denied',
#  'movie',
#  'anything',
#  'kurten',
#  'yet',
#  'similiarity',
#  'film',
#  'murders',
#  'occurred',
#  'though',
#  'could',
#  'coincidencethis',
#  'definitely',
#  'acquired',
#  'taste',
#  'everyonebut',
#  'say',
#  'short',
#  'attention',
#  'span',
#  'dont',
#  'buy',
#  'film']

# %%
cur_df[REVIEW_TEXT].tolist()[0]
# Out:
# 'Filmed in 1931 this is the first serial killer movie...M is the story of a serial killer who terrorizes a German town. As you follow the story you get to see the city going mad, the hunt for the killer, the killer at work and then eventually Lorre fleeing for his life.. Before the killer strikes hes always whistling this haunting tune, very eerie. A blind man who sells balloons ends up using his keen observances and hearing of the whistling and putting 2 and 2 together...eventually aiding in his capture and bringing the killer to justice.The imagery is haunting,the whistling is creepy and really grates on your nerves, the scariness is more of a what you dont see kind of deal  ... Ive also have heard this film somewhat models the story of German serial killer Peter Kurten aka the Vampire of Dusseldorf who in 1929 was commiting assaults and murders of children. Fritz denied the movie having anything to do with Kurten yet there is a similiarity between the film and the murders that occurred... though this could have been a coincidence.This is definitely an acquired taste.. Not for everyoneBut I have to say this...If you have a short attention span, dont buy this film.'

# %%
token_list[4]
# Out:
# ['dark',
#  'disturbingly',
#  'satirical',
#  'humorous',
#  'exactly',
#  'would',
#  'nt',
#  'expect',
#  'populated',
#  'strangelooking',
#  'people',
#  'would',
#  'result',
#  'george',
#  'grosz',
#  'film',
#  'director']

# %%
cur_df[REVIEW_TEXT].tolist()[4]
# Out:
# "Dark, disturbingly satirical, humorous exactly where you wouldn't expect it to be, and populated by strange-looking people, this would be the result if George Grosz had been a film director."
