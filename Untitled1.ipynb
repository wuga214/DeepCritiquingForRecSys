# %%
import pandas as pd

# %%
from utils.io import load_dataframe_folder

# %%
df = load_dataframe_folder('tables/CD_final')

# %%
df.head()
# Out:
#    model  rank  num_layers  train_batch_size  predict_batch_size   lambda  \
# 0   CNCF   100           1               128                 128  0.00100
# 1   VNCF   200           1               128                 128  0.00005
# 2    NCF   100           1               128                 128  0.00010
# 3  IVNCF   200           1               128                 128  0.00005
# 4   INCF   100           1               128                 128  0.00100
#
#    topK  learning_rate  epoch  negative_sampling_size    ...      \
# 0    50         0.0005    NaN                       5    ...
# 1    50         0.0001    NaN                       5    ...
# 2    50         0.0005    NaN                       5    ...
# 3    50         0.0001    NaN                       5    ...
# 4    50         0.0005    NaN                       5    ...
#
#    Precision@15  Precision@20  Precision@5  Precision@50  R-Precision  \
# 0        0.0449        0.0407       0.0649        0.0272       0.0644
# 1        0.0459        0.0412       0.0646        0.0279       0.0669
# 2        0.0446        0.0398       0.0626        0.0270       0.0631
# 3        0.0468        0.0419       0.0647        0.0281       0.0670
# 4        0.0456        0.0413       0.0639        0.0276       0.0658
#
#    Recall@10  Recall@15  Recall@20  Recall@5  Recall@50
# 0     0.1263     0.1608     0.1898    0.0813     0.3037
# 1     0.1350     0.1709     0.2016    0.0826     0.3229
# 2     0.1257     0.1603     0.1887    0.0802     0.3044
# 3     0.1339     0.1723     0.2019    0.0842     0.3235
# 4     0.1276     0.1638     0.1950    0.0826     0.3094
#
# [5 rows x 28 columns]

# %%
df = df.drop(['rank','num_layers','train_batch_size','predict_batch_size','lambda','topK','learning_rate','epoch','negative_sampling_size','Clicks'], axis=1)

# %%
df = df.groupby(['model']).mean().reset_index()

# %%
df.to_csv('tables/CD_final/final.csv')

# %%
df_baseline = pd.read_csv('tables/CD_final/baselines/final_baselines.csv')

# %%
df_baseline = df_baseline.drop(['rank','alpha','lambda','iter','similarity','corruption','root','topK'], axis=1)

# %%
import ast
def remove_val(string):
    l = ast.literal_eval(string)
    return l[0]

# %%
columns = list(df_baseline.columns)

# %%
columns.pop(0)
# Out:
# 'model'

# %%
columns
# Out:
# ['MAP@10',
#  'MAP@15',
#  'MAP@20',
#  'MAP@5',
#  'MAP@50',
#  'NDCG',
#  'Precision@10',
#  'Precision@15',
#  'Precision@20',
#  'Precision@5',
#  'Precision@50',
#  'R-Precision',
#  'Recall@10',
#  'Recall@15',
#  'Recall@20',
#  'Recall@5',
#  'Recall@50',
#  'metric']

# %%
for c in columns:
    df_baseline[c] = df_baseline[c].apply(lambda x: remove_val(x))

# %%
df_baseline
# Out:
#        model  MAP@10  MAP@15  MAP@20   MAP@5  MAP@50    NDCG  Precision@10  \
# 0       CDAE  0.0113  0.0108  0.0105  0.0115  0.0091  0.0313        0.0107
# 1        POP  0.0094  0.0091  0.0088  0.0096  0.0078  0.0277        0.0087
# 2       WRMF  0.0808  0.0738  0.0684  0.0905  0.0509  0.1922        0.0656
# 3      PLRec  0.0734  0.0660  0.0606  0.0839  0.0441  0.1621        0.0574
# 4     VAE-CF  0.0730  0.0665  0.0616  0.0831  0.0460  0.1801        0.0585
# 5        CML  0.0294  0.0274  0.0258  0.0316  0.0199  0.0670        0.0253
# 6    AutoRec  0.0154  0.0144  0.0137  0.0166  0.0113  0.0387        0.0133
# 7  NCE-PLRec  0.0740  0.0670  0.0617  0.0844  0.0449  0.1667        0.0583
# 8    PureSVD  0.0678  0.0610  0.0559  0.0780  0.0403  0.1511        0.0523
# 9        BPR  0.0625  0.0566  0.0524  0.0719  0.0399  0.1527        0.0489
#
#    Precision@15  Precision@20  Precision@5  Precision@50  R-Precision  \
# 0        0.0097        0.0094       0.0115        0.0073       0.0090
# 1        0.0083        0.0079       0.0099        0.0065       0.0078
# 2        0.0561        0.0497       0.0814        0.0325       0.0830
# 3        0.0481        0.0424       0.0727        0.0273       0.0732
# 4        0.0504        0.0447       0.0727        0.0299       0.0769
# 5        0.0223        0.0199       0.0303        0.0136       0.0273
# 6        0.0121        0.0113       0.0152        0.0087       0.0130
# 7        0.0498        0.0436       0.0732        0.0275       0.0745
# 8        0.0444        0.0389       0.0671        0.0243       0.0681
# 9        0.0424        0.0384       0.0612        0.0270       0.0621
#
#    Recall@10  Recall@15  Recall@20  Recall@5  Recall@50       metric
# 0     0.0206     0.0277     0.0365    0.0108     0.0694  R-Precision
# 1     0.0164     0.0250     0.0317    0.0088     0.0625  R-Precision
# 2     0.1609     0.2021     0.2345    0.1035     0.3597  R-Precision
# 3     0.1354     0.1659     0.1931    0.0892     0.2938  R-Precision
# 4     0.1475     0.1851     0.2152    0.0956     0.3414  R-Precision
# 5     0.0528     0.0681     0.0798    0.0313     0.1304  R-Precision
# 6     0.0252     0.0345     0.0430    0.0144     0.0807  R-Precision
# 7     0.1398     0.1748     0.2015    0.0898     0.3043  R-Precision
# 8     0.1280     0.1588     0.1821    0.0846     0.2743  R-Precision
# 9     0.1160     0.1479     0.1755    0.0751     0.2975  R-Precision

# %%
df_baseline.to_csv('tables/CD_final/baselines/final_baseline.csv')
